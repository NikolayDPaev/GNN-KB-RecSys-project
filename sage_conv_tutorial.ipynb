# %%
import torch
import torch.nn.functional as F
from torch_geometric.nn import SAGEConv, to_hetero
from torch_geometric.data import HeteroData
import torch_geometric.transforms as T
from sentence_transformers import SentenceTransformer
import pandas as pd

from IPython import get_ipython # type: ignore
import os

torch.manual_seed(0)

# get the notebook name
ip = get_ipython()
path = None
if '__vsc_ipynb_file__' in ip.user_ns: # type: ignore
    path = ip.user_ns['__vsc_ipynb_file__'] # type: ignore

os.makedirs('models/', exist_ok=True)
model_file_name = f"models/{os.path.basename(path)[:-6]}.pt" # type: ignore

# %% [markdown]
# Data

# %%
movie_path = 'dataset/ml-latest-small/movies.csv'
rating_path = 'dataset/ml-latest-small/ratings.csv'

# Load the entire ratings dataframe into memory:
ratings_df = pd.read_csv(rating_path)[["userId", "movieId", "rating"]]

# Load the entire movie dataframe into memory:
movies_df = pd.read_csv(movie_path, index_col='movieId')

# %%
# One-hot encode the genres:
genres = movies_df['genres'].str.get_dummies('|').values
genres = torch.from_numpy(genres).to(torch.float)

# Load the pre-trained sentence transformer model and encode the movie titles:
model = SentenceTransformer('all-MiniLM-L6-v2')
with torch.no_grad():
    titles = model.encode(movies_df['title'].tolist(), convert_to_tensor=True, show_progress_bar=True)
    titles = titles.cpu()

# Concatenate the genres and title features:
movie_features = torch.cat([genres, titles], dim=-1)

# We don't have user features, which is why we use an identity matrix
user_features = torch.eye(len(ratings_df['userId'].unique()))
# Out:
# Batches:   0%|          | 0/305 [00:00<?, ?it/s]

# %%
unique_user_id = ratings_df['userId'].unique()
unique_user_id = pd.DataFrame(data={
    'userId': unique_user_id,
    'mappedUserId': pd.RangeIndex(len(unique_user_id))
    })

# Create a mapping from the movieId to a unique consecutive value in the range [0, num_movies]:
unique_movie_id = ratings_df['movieId'].unique()
unique_movie_id = pd.DataFrame(data={
    'movieId': unique_movie_id,
    'mappedMovieId': pd.RangeIndex(len(unique_movie_id))
    })

# Merge the mappings with the original data frame:
ratings_df = ratings_df.merge(unique_user_id, on='userId')
ratings_df = ratings_df.merge(unique_movie_id, on='movieId')

# With this, we are ready to create the edge_index representation in COO format
# following the PyTorch Geometric semantics:
edge_index = torch.stack([
    torch.tensor(ratings_df['mappedUserId'].values),
    torch.tensor(ratings_df['mappedMovieId'].values)]
    , dim=0)

assert edge_index.shape == (2, len(ratings_df))

# %%
# Create the heterogeneous graph data object:
data = HeteroData()

# Add the user nodes:
data['user'].x = user_features  # [num_users, num_features_users]

# Add the movie nodes:
data['movie'].x = movie_features  # [num_movies, num_features_movies]

# Add the rating edges:
data['user', 'rates', 'movie'].edge_index = edge_index  # [2, num_ratings]

# Add the rating labels:
rating = torch.from_numpy(ratings_df['rating'].values).to(torch.float)
data['user', 'rates', 'movie'].edge_label = rating  # [num_ratings]

# We also need to make sure to add the reverse edges from movies to users
# in order to let a GNN be able to pass messages in both directions.
# We can leverage the `T.ToUndirected()` transform for this from PyG:
data = T.ToUndirected()(data)

# With the above transformation we also got reversed labels for the edges.
# We are going to remove them:
del data['movie', 'rev_rates', 'user'].edge_label

assert data['user'].num_nodes == len(unique_user_id)
assert data['user', 'rates', 'movie'].num_edges == len(ratings_df)
assert data['movie'].num_features == 404

data
# Out:
# HeteroData(
#   user={ x=[610, 610] },
#   movie={ x=[9742, 404] },
#   (user, rates, movie)={
#     edge_index=[2, 100836],
#     edge_label=[100836],
#   },
#   (movie, rev_rates, user)={ edge_index=[2, 100836] }
# )

# %%
class GNNEncoder(torch.nn.Module):
    def __init__(self, hidden_channels, out_channels):
        super().__init__()
        self.conv1 = SAGEConv((-1, -1), hidden_channels)
        self.conv2 = SAGEConv((-1, -1), out_channels)

    def forward(self, x, edge_index):
        x = self.conv1(x, edge_index).relu()
        x = self.conv2(x, edge_index)
        return x


class EdgeDecoder(torch.nn.Module):
    def __init__(self, hidden_channels):
        super().__init__()
        self.lin1 = torch.nn.Linear(2 * hidden_channels, hidden_channels)
        self.lin2 = torch.nn.Linear(hidden_channels, 1)

    def forward(self, z_dict, edge_label_index):
        row, col = edge_label_index
        z = torch.cat([z_dict['user'][row], z_dict['movie'][col]], dim=-1)

        z = self.lin1(z).relu()
        z = self.lin2(z)
        return z.view(-1)


class Model(torch.nn.Module):
    def __init__(self, hidden_channels):
        super().__init__()
        self.encoder = GNNEncoder(hidden_channels, hidden_channels)
        self.encoder = to_hetero(self.encoder, data.metadata(), aggr='sum')
        self.decoder = EdgeDecoder(hidden_channels)

    def forward(self, x_dict, edge_index_dict, edge_label_index):
        z_dict = self.encoder(x_dict, edge_index_dict)
        return self.decoder(z_dict, edge_label_index)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model = Model(hidden_channels=32).to(device)

print(model)
# Out:
# Model(
#   (encoder): GraphModule(
#     (conv1): ModuleDict(
#       (user__rates__movie): SAGEConv((-1, -1), 32, aggr=mean)
#       (movie__rev_rates__user): SAGEConv((-1, -1), 32, aggr=mean)
#     )
#     (conv2): ModuleDict(
#       (user__rates__movie): SAGEConv((-1, -1), 32, aggr=mean)
#       (movie__rev_rates__user): SAGEConv((-1, -1), 32, aggr=mean)
#     )
#   )
#   (decoder): EdgeDecoder(
#     (lin1): Linear(in_features=64, out_features=32, bias=True)
#     (lin2): Linear(in_features=32, out_features=1, bias=True)
#   )
# )

# %%
train_data, val_data, test_data = T.RandomLinkSplit(
    num_val=0.1,
    num_test=0.1,
    neg_sampling_ratio=0.0,
    edge_types=[('user', 'rates', 'movie')],
    rev_edge_types=[('movie', 'rev_rates', 'user')],
)(data)

# %%
# Initialize optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

# Define training function
def train(model):
    model.train()
    optimizer.zero_grad()
    pred = model(train_data.x_dict, train_data.edge_index_dict,
                 train_data['user', 'movie'].edge_label_index)
    target = train_data['user', 'movie'].edge_label
    loss = F.mse_loss(pred, target)
    loss.backward()
    optimizer.step()
    return float(loss)

# Define test function
@torch.no_grad()
def test(model, data):
    data = data.to(device)
    model.eval()
    pred = model(data.x_dict, data.edge_index_dict,
                 data['user', 'movie'].edge_label_index)
    pred = pred.clamp(min=0, max=5)
    target = data['user', 'movie'].edge_label.float()
    rmse = F.mse_loss(pred, target).sqrt()
    return float(rmse)

best_val_rmse = float('inf')
best_epoch = 0

# Training loop
for epoch in range(1, 201):
    train_data = train_data.to(device)
    loss = train(model)
    train_rmse = test(model, train_data)
    val_rmse = test(model, val_data)

    # Check if the current validation RMSE is the best
    if val_rmse < best_val_rmse:
        best_val_rmse = val_rmse
        best_epoch = epoch
        torch.save(model.state_dict(), model_file_name)
        print(f'Saving model with val_rmse: {val_rmse:.4f} at epoch {epoch}')

    print(f'Epoch: {epoch:03d}, Loss: {loss:.4f}, Train: {train_rmse:.4f}, Val: {val_rmse:.4f}')
# Out:
# Saving model with val_rmse: 3.4645 at epoch 1
# Epoch: 001, Loss: 13.4508, Train: 3.4719, Val: 3.4645
# Saving model with val_rmse: 3.1816 at epoch 2
# Epoch: 002, Loss: 12.0540, Train: 3.1875, Val: 3.1816
# Saving model with val_rmse: 2.6913 at epoch 3
# Epoch: 003, Loss: 10.1602, Train: 2.6941, Val: 2.6913
# Saving model with val_rmse: 1.8866 at epoch 4
# Epoch: 004, Loss: 7.2583, Train: 1.8839, Val: 1.8866
# Saving model with val_rmse: 1.0424 at epoch 5
# Epoch: 005, Loss: 3.5489, Train: 1.0392, Val: 1.0424
# Epoch: 006, Loss: 1.0800, Train: 1.8153, Val: 1.7997
# Epoch: 007, Loss: 4.5266, Train: 1.7762, Val: 1.7594
# Epoch: 008, Loss: 3.5703, Train: 1.2131, Val: 1.2071
# Epoch: 009, Loss: 1.4716, Train: 1.0716, Val: 1.0767
# Epoch: 010, Loss: 1.1484, Train: 1.3770, Val: 1.3822
# Epoch: 011, Loss: 1.8961, Train: 1.5865, Val: 1.5903
# Epoch: 012, Loss: 2.5169, Train: 1.6152, Val: 1.6188
# Epoch: 013, Loss: 2.6090, Train: 1.4997, Val: 1.5041
# Epoch: 014, Loss: 2.2490, Train: 1.2923, Val: 1.2981
# Epoch: 015, Loss: 1.6700, Train: 1.0837, Val: 1.0897
# Saving model with val_rmse: 1.0292 at epoch 16
# Epoch: 016, Loss: 1.1743, Train: 1.0268, Val: 1.0292
# Epoch: 017, Loss: 1.0542, Train: 1.1678, Val: 1.1645
# Epoch: 018, Loss: 1.3638, Train: 1.3065, Val: 1.3000
# Epoch: 019, Loss: 1.7070, Train: 1.2846, Val: 1.2788
# Epoch: 020, Loss: 1.6503, Train: 1.1426, Val: 1.1405
# Saving model with val_rmse: 1.0268 at epoch 21
# Epoch: 021, Loss: 1.3055, Train: 1.0239, Val: 1.0268
# Saving model with val_rmse: 1.0244 at epoch 22
# Epoch: 022, Loss: 1.0484, Train: 1.0182, Val: 1.0244
# Epoch: 023, Loss: 1.0367, Train: 1.0852, Val: 1.0925
# Epoch: 024, Loss: 1.1777, Train: 1.1476, Val: 1.1549
# Epoch: 025, Loss: 1.3169, Train: 1.1653, Val: 1.1728
# Epoch: 026, Loss: 1.3580, Train: 1.1336, Val: 1.1413
# Epoch: 027, Loss: 1.2851, Train: 1.0701, Val: 1.0779
# Saving model with val_rmse: 1.0176 at epoch 28
# Epoch: 028, Loss: 1.1451, Train: 1.0102, Val: 1.0176
# Saving model with val_rmse: 0.9985 at epoch 29
# Epoch: 029, Loss: 1.0205, Train: 0.9928, Val: 0.9985
# Epoch: 030, Loss: 0.9856, Train: 1.0247, Val: 1.0282
# Epoch: 031, Loss: 1.0501, Train: 1.0658, Val: 1.0675
# Epoch: 032, Loss: 1.1359, Train: 1.0709, Val: 1.0726
# Epoch: 033, Loss: 1.1469, Train: 1.0358, Val: 1.0390
# Epoch: 034, Loss: 1.0729, Train: 0.9939, Val: 0.9994
# Saving model with val_rmse: 0.9860 at epoch 35
# Epoch: 035, Loss: 0.9879, Train: 0.9785, Val: 0.9860
# Epoch: 036, Loss: 0.9574, Train: 0.9916, Val: 1.0004
# Epoch: 037, Loss: 0.9833, Train: 1.0121, Val: 1.0214
# Epoch: 038, Loss: 1.0243, Train: 1.0198, Val: 1.0294
# Epoch: 039, Loss: 1.0401, Train: 1.0086, Val: 1.0183
# Epoch: 040, Loss: 1.0173, Train: 0.9861, Val: 0.9956
# Saving model with val_rmse: 0.9765 at epoch 41
# Epoch: 041, Loss: 0.9723, Train: 0.9675, Val: 0.9765
# Saving model with val_rmse: 0.9729 at epoch 42
# Epoch: 042, Loss: 0.9361, Train: 0.9650, Val: 0.9729
# Epoch: 043, Loss: 0.9312, Train: 0.9756, Val: 0.9824
# Epoch: 044, Loss: 0.9519, Train: 0.9844, Val: 0.9905
# Epoch: 045, Loss: 0.9690, Train: 0.9798, Val: 0.9862
# Saving model with val_rmse: 0.9727 at epoch 46
# Epoch: 046, Loss: 0.9600, Train: 0.9654, Val: 0.9727
# Saving model with val_rmse: 0.9622 at epoch 47
# Epoch: 047, Loss: 0.9319, Train: 0.9535, Val: 0.9622
# Saving model with val_rmse: 0.9616 at epoch 48
# Epoch: 048, Loss: 0.9092, Train: 0.9518, Val: 0.9616
# Epoch: 049, Loss: 0.9060, Train: 0.9570, Val: 0.9675
# Epoch: 050, Loss: 0.9159, Train: 0.9606, Val: 0.9714
# Epoch: 051, Loss: 0.9227, Train: 0.9574, Val: 0.9683
# Saving model with val_rmse: 0.9598 at epoch 52
# Epoch: 052, Loss: 0.9167, Train: 0.9491, Val: 0.9598
# Saving model with val_rmse: 0.9516 at epoch 53
# Epoch: 053, Loss: 0.9008, Train: 0.9414, Val: 0.9516
# Saving model with val_rmse: 0.9487 at epoch 54
# Epoch: 054, Loss: 0.8863, Train: 0.9393, Val: 0.9487
# Epoch: 055, Loss: 0.8823, Train: 0.9417, Val: 0.9504
# Epoch: 056, Loss: 0.8868, Train: 0.9432, Val: 0.9516
# Epoch: 057, Loss: 0.8897, Train: 0.9402, Val: 0.9488
# Saving model with val_rmse: 0.9435 at epoch 58
# Epoch: 058, Loss: 0.8840, Train: 0.9343, Val: 0.9435
# Saving model with val_rmse: 0.9400 at epoch 59
# Epoch: 059, Loss: 0.8730, Train: 0.9301, Val: 0.9400
# Epoch: 060, Loss: 0.8650, Train: 0.9294, Val: 0.9401
# Epoch: 061, Loss: 0.8639, Train: 0.9305, Val: 0.9416
# Epoch: 062, Loss: 0.8658, Train: 0.9301, Val: 0.9414
# Saving model with val_rmse: 0.9384 at epoch 63
# Epoch: 063, Loss: 0.8651, Train: 0.9272, Val: 0.9384
# Saving model with val_rmse: 0.9343 at epoch 64
# Epoch: 064, Loss: 0.8597, Train: 0.9235, Val: 0.9343
# Saving model with val_rmse: 0.9317 at epoch 65
# Epoch: 065, Loss: 0.8529, Train: 0.9214, Val: 0.9317
# Saving model with val_rmse: 0.9311 at epoch 66
# Epoch: 066, Loss: 0.8489, Train: 0.9213, Val: 0.9311
# Saving model with val_rmse: 0.9311 at epoch 67
# Epoch: 067, Loss: 0.8488, Train: 0.9216, Val: 0.9311
# Saving model with val_rmse: 0.9299 at epoch 68
# Epoch: 068, Loss: 0.8494, Train: 0.9204, Val: 0.9299
# Saving model with val_rmse: 0.9279 at epoch 69
# Epoch: 069, Loss: 0.8472, Train: 0.9180, Val: 0.9279
# Saving model with val_rmse: 0.9264 at epoch 70
# Epoch: 070, Loss: 0.8427, Train: 0.9160, Val: 0.9264
# Saving model with val_rmse: 0.9263 at epoch 71
# Epoch: 071, Loss: 0.8391, Train: 0.9154, Val: 0.9263
# Epoch: 072, Loss: 0.8380, Train: 0.9156, Val: 0.9268
# Epoch: 073, Loss: 0.8383, Train: 0.9151, Val: 0.9264
# Saving model with val_rmse: 0.9250 at epoch 74
# Epoch: 074, Loss: 0.8374, Train: 0.9138, Val: 0.9250
# Saving model with val_rmse: 0.9232 at epoch 75
# Epoch: 075, Loss: 0.8350, Train: 0.9123, Val: 0.9232
# Saving model with val_rmse: 0.9222 at epoch 76
# Epoch: 076, Loss: 0.8323, Train: 0.9116, Val: 0.9222
# Saving model with val_rmse: 0.9219 at epoch 77
# Epoch: 077, Loss: 0.8311, Train: 0.9116, Val: 0.9219
# Saving model with val_rmse: 0.9216 at epoch 78
# Epoch: 078, Loss: 0.8311, Train: 0.9115, Val: 0.9216
# Saving model with val_rmse: 0.9210 at epoch 79
# Epoch: 079, Loss: 0.8308, Train: 0.9107, Val: 0.9210
# Saving model with val_rmse: 0.9204 at epoch 80
# Epoch: 080, Loss: 0.8293, Train: 0.9097, Val: 0.9204
# Saving model with val_rmse: 0.9202 at epoch 81
# Epoch: 081, Loss: 0.8275, Train: 0.9091, Val: 0.9202
# Epoch: 082, Loss: 0.8265, Train: 0.9090, Val: 0.9205
# Epoch: 083, Loss: 0.8264, Train: 0.9089, Val: 0.9206
# Saving model with val_rmse: 0.9201 at epoch 84
# Epoch: 084, Loss: 0.8261, Train: 0.9084, Val: 0.9201
# Saving model with val_rmse: 0.9193 at epoch 85
# Epoch: 085, Loss: 0.8252, Train: 0.9077, Val: 0.9193
# Saving model with val_rmse: 0.9187 at epoch 86
# Epoch: 086, Loss: 0.8240, Train: 0.9073, Val: 0.9187
# Saving model with val_rmse: 0.9184 at epoch 87
# Epoch: 087, Loss: 0.8232, Train: 0.9072, Val: 0.9184
# Saving model with val_rmse: 0.9183 at epoch 88
# Epoch: 088, Loss: 0.8229, Train: 0.9070, Val: 0.9183
# Saving model with val_rmse: 0.9180 at epoch 89
# Epoch: 089, Loss: 0.8226, Train: 0.9066, Val: 0.9180
# Saving model with val_rmse: 0.9178 at epoch 90
# Epoch: 090, Loss: 0.8219, Train: 0.9061, Val: 0.9178
# Epoch: 091, Loss: 0.8210, Train: 0.9057, Val: 0.9178
# Epoch: 092, Loss: 0.8203, Train: 0.9055, Val: 0.9180
# Epoch: 093, Loss: 0.8199, Train: 0.9053, Val: 0.9179
# Saving model with val_rmse: 0.9177 at epoch 94
# Epoch: 094, Loss: 0.8195, Train: 0.9049, Val: 0.9177
# Saving model with val_rmse: 0.9172 at epoch 95
# Epoch: 095, Loss: 0.8188, Train: 0.9044, Val: 0.9172
# Saving model with val_rmse: 0.9169 at epoch 96
# Epoch: 096, Loss: 0.8180, Train: 0.9041, Val: 0.9169
# Saving model with val_rmse: 0.9166 at epoch 97
# Epoch: 097, Loss: 0.8174, Train: 0.9039, Val: 0.9166
# Saving model with val_rmse: 0.9165 at epoch 98
# Epoch: 098, Loss: 0.8170, Train: 0.9036, Val: 0.9165
# Saving model with val_rmse: 0.9163 at epoch 99
# Epoch: 099, Loss: 0.8165, Train: 0.9032, Val: 0.9163
# Saving model with val_rmse: 0.9163 at epoch 100
# Epoch: 100, Loss: 0.8158, Train: 0.9028, Val: 0.9163
# Epoch: 101, Loss: 0.8151, Train: 0.9025, Val: 0.9163
# Epoch: 102, Loss: 0.8145, Train: 0.9022, Val: 0.9163
# Saving model with val_rmse: 0.9161 at epoch 103
# Epoch: 103, Loss: 0.8140, Train: 0.9019, Val: 0.9161
# Saving model with val_rmse: 0.9159 at epoch 104
# Epoch: 104, Loss: 0.8134, Train: 0.9015, Val: 0.9159
# Saving model with val_rmse: 0.9156 at epoch 105
# Epoch: 105, Loss: 0.8127, Train: 0.9012, Val: 0.9156
# Saving model with val_rmse: 0.9154 at epoch 106
# Epoch: 106, Loss: 0.8121, Train: 0.9008, Val: 0.9154
# Saving model with val_rmse: 0.9152 at epoch 107
# Epoch: 107, Loss: 0.8115, Train: 0.9005, Val: 0.9152
# Saving model with val_rmse: 0.9150 at epoch 108
# Epoch: 108, Loss: 0.8110, Train: 0.9002, Val: 0.9150
# Saving model with val_rmse: 0.9149 at epoch 109
# Epoch: 109, Loss: 0.8104, Train: 0.8998, Val: 0.9149
# Saving model with val_rmse: 0.9149 at epoch 110
# Epoch: 110, Loss: 0.8097, Train: 0.8995, Val: 0.9149
# Saving model with val_rmse: 0.9148 at epoch 111
# Epoch: 111, Loss: 0.8091, Train: 0.8992, Val: 0.9148
# Saving model with val_rmse: 0.9147 at epoch 112
# Epoch: 112, Loss: 0.8086, Train: 0.8989, Val: 0.9147
# Saving model with val_rmse: 0.9145 at epoch 113
# Epoch: 113, Loss: 0.8080, Train: 0.8985, Val: 0.9145
# Saving model with val_rmse: 0.9143 at epoch 114
# Epoch: 114, Loss: 0.8073, Train: 0.8982, Val: 0.9143
# Saving model with val_rmse: 0.9140 at epoch 115
# Epoch: 115, Loss: 0.8067, Train: 0.8978, Val: 0.9140
# Saving model with val_rmse: 0.9138 at epoch 116
# Epoch: 116, Loss: 0.8061, Train: 0.8975, Val: 0.9138
# Saving model with val_rmse: 0.9137 at epoch 117
# Epoch: 117, Loss: 0.8055, Train: 0.8971, Val: 0.9137
# Saving model with val_rmse: 0.9135 at epoch 118
# Epoch: 118, Loss: 0.8049, Train: 0.8968, Val: 0.9135
# Saving model with val_rmse: 0.9134 at epoch 119
# Epoch: 119, Loss: 0.8042, Train: 0.8964, Val: 0.9134
# Saving model with val_rmse: 0.9133 at epoch 120
# Epoch: 120, Loss: 0.8036, Train: 0.8961, Val: 0.9133
# Saving model with val_rmse: 0.9132 at epoch 121
# Epoch: 121, Loss: 0.8030, Train: 0.8957, Val: 0.9132
# Saving model with val_rmse: 0.9130 at epoch 122
# Epoch: 122, Loss: 0.8023, Train: 0.8954, Val: 0.9130
# Saving model with val_rmse: 0.9127 at epoch 123
# Epoch: 123, Loss: 0.8017, Train: 0.8950, Val: 0.9127
# Saving model with val_rmse: 0.9125 at epoch 124
# Epoch: 124, Loss: 0.8010, Train: 0.8946, Val: 0.9125
# Saving model with val_rmse: 0.9123 at epoch 125
# Epoch: 125, Loss: 0.8004, Train: 0.8943, Val: 0.9123
# Saving model with val_rmse: 0.9121 at epoch 126
# Epoch: 126, Loss: 0.7997, Train: 0.8939, Val: 0.9121
# Saving model with val_rmse: 0.9119 at epoch 127
# Epoch: 127, Loss: 0.7991, Train: 0.8935, Val: 0.9119
# Saving model with val_rmse: 0.9118 at epoch 128
# Epoch: 128, Loss: 0.7984, Train: 0.8931, Val: 0.9118
# Saving model with val_rmse: 0.9116 at epoch 129
# Epoch: 129, Loss: 0.7977, Train: 0.8927, Val: 0.9116
# Saving model with val_rmse: 0.9114 at epoch 130
# Epoch: 130, Loss: 0.7970, Train: 0.8924, Val: 0.9114
# Saving model with val_rmse: 0.9112 at epoch 131
# Epoch: 131, Loss: 0.7963, Train: 0.8920, Val: 0.9112
# Saving model with val_rmse: 0.9109 at epoch 132
# Epoch: 132, Loss: 0.7956, Train: 0.8916, Val: 0.9109
# Saving model with val_rmse: 0.9107 at epoch 133
# Epoch: 133, Loss: 0.7949, Train: 0.8912, Val: 0.9107
# Saving model with val_rmse: 0.9105 at epoch 134
# Epoch: 134, Loss: 0.7942, Train: 0.8908, Val: 0.9105
# Saving model with val_rmse: 0.9103 at epoch 135
# Epoch: 135, Loss: 0.7935, Train: 0.8904, Val: 0.9103
# Saving model with val_rmse: 0.9101 at epoch 136
# Epoch: 136, Loss: 0.7928, Train: 0.8900, Val: 0.9101
# Saving model with val_rmse: 0.9099 at epoch 137
# Epoch: 137, Loss: 0.7921, Train: 0.8896, Val: 0.9099
# Saving model with val_rmse: 0.9097 at epoch 138
# Epoch: 138, Loss: 0.7913, Train: 0.8891, Val: 0.9097
# Saving model with val_rmse: 0.9095 at epoch 139
# Epoch: 139, Loss: 0.7906, Train: 0.8887, Val: 0.9095
# Saving model with val_rmse: 0.9092 at epoch 140
# Epoch: 140, Loss: 0.7899, Train: 0.8883, Val: 0.9092
# Saving model with val_rmse: 0.9090 at epoch 141
# Epoch: 141, Loss: 0.7891, Train: 0.8879, Val: 0.9090
# Saving model with val_rmse: 0.9088 at epoch 142
# Epoch: 142, Loss: 0.7884, Train: 0.8875, Val: 0.9088
# Saving model with val_rmse: 0.9086 at epoch 143
# Epoch: 143, Loss: 0.7876, Train: 0.8870, Val: 0.9086
# Saving model with val_rmse: 0.9084 at epoch 144
# Epoch: 144, Loss: 0.7869, Train: 0.8866, Val: 0.9084
# Saving model with val_rmse: 0.9082 at epoch 145
# Epoch: 145, Loss: 0.7861, Train: 0.8862, Val: 0.9082
# Saving model with val_rmse: 0.9080 at epoch 146
# Epoch: 146, Loss: 0.7853, Train: 0.8857, Val: 0.9080
# Saving model with val_rmse: 0.9078 at epoch 147
# Epoch: 147, Loss: 0.7846, Train: 0.8853, Val: 0.9078
# Saving model with val_rmse: 0.9075 at epoch 148
# Epoch: 148, Loss: 0.7838, Train: 0.8849, Val: 0.9075
# Saving model with val_rmse: 0.9073 at epoch 149
# Epoch: 149, Loss: 0.7830, Train: 0.8844, Val: 0.9073
# Saving model with val_rmse: 0.9071 at epoch 150
# Epoch: 150, Loss: 0.7823, Train: 0.8840, Val: 0.9071
# Saving model with val_rmse: 0.9069 at epoch 151
# Epoch: 151, Loss: 0.7815, Train: 0.8835, Val: 0.9069
# Saving model with val_rmse: 0.9067 at epoch 152
# Epoch: 152, Loss: 0.7807, Train: 0.8831, Val: 0.9067
# Saving model with val_rmse: 0.9065 at epoch 153
# Epoch: 153, Loss: 0.7799, Train: 0.8826, Val: 0.9065
# Saving model with val_rmse: 0.9063 at epoch 154
# Epoch: 154, Loss: 0.7791, Train: 0.8822, Val: 0.9063
# Saving model with val_rmse: 0.9062 at epoch 155
# Epoch: 155, Loss: 0.7783, Train: 0.8817, Val: 0.9062
# Saving model with val_rmse: 0.9060 at epoch 156
# Epoch: 156, Loss: 0.7775, Train: 0.8813, Val: 0.9060
# Saving model with val_rmse: 0.9058 at epoch 157
# Epoch: 157, Loss: 0.7767, Train: 0.8808, Val: 0.9058
# Saving model with val_rmse: 0.9056 at epoch 158
# Epoch: 158, Loss: 0.7759, Train: 0.8804, Val: 0.9056
# Saving model with val_rmse: 0.9054 at epoch 159
# Epoch: 159, Loss: 0.7751, Train: 0.8799, Val: 0.9054
# Saving model with val_rmse: 0.9052 at epoch 160
# Epoch: 160, Loss: 0.7743, Train: 0.8795, Val: 0.9052
# Saving model with val_rmse: 0.9051 at epoch 161
# Epoch: 161, Loss: 0.7735, Train: 0.8790, Val: 0.9051
# Saving model with val_rmse: 0.9049 at epoch 162
# Epoch: 162, Loss: 0.7727, Train: 0.8785, Val: 0.9049
# Saving model with val_rmse: 0.9048 at epoch 163
# Epoch: 163, Loss: 0.7719, Train: 0.8781, Val: 0.9048
# Saving model with val_rmse: 0.9046 at epoch 164
# Epoch: 164, Loss: 0.7711, Train: 0.8776, Val: 0.9046
# Saving model with val_rmse: 0.9045 at epoch 165
# Epoch: 165, Loss: 0.7703, Train: 0.8772, Val: 0.9045
# Saving model with val_rmse: 0.9043 at epoch 166
# Epoch: 166, Loss: 0.7695, Train: 0.8767, Val: 0.9043
# Saving model with val_rmse: 0.9042 at epoch 167
# Epoch: 167, Loss: 0.7688, Train: 0.8763, Val: 0.9042
# Saving model with val_rmse: 0.9040 at epoch 168
# Epoch: 168, Loss: 0.7680, Train: 0.8758, Val: 0.9040
# Saving model with val_rmse: 0.9039 at epoch 169
# Epoch: 169, Loss: 0.7672, Train: 0.8754, Val: 0.9039
# Saving model with val_rmse: 0.9038 at epoch 170
# Epoch: 170, Loss: 0.7664, Train: 0.8749, Val: 0.9038
# Saving model with val_rmse: 0.9037 at epoch 171
# Epoch: 171, Loss: 0.7656, Train: 0.8745, Val: 0.9037
# Saving model with val_rmse: 0.9036 at epoch 172
# Epoch: 172, Loss: 0.7649, Train: 0.8741, Val: 0.9036
# Saving model with val_rmse: 0.9035 at epoch 173
# Epoch: 173, Loss: 0.7641, Train: 0.8736, Val: 0.9035
# Saving model with val_rmse: 0.9034 at epoch 174
# Epoch: 174, Loss: 0.7634, Train: 0.8732, Val: 0.9034
# Saving model with val_rmse: 0.9033 at epoch 175
# Epoch: 175, Loss: 0.7626, Train: 0.8728, Val: 0.9033
# Saving model with val_rmse: 0.9032 at epoch 176
# Epoch: 176, Loss: 0.7619, Train: 0.8724, Val: 0.9032
# Saving model with val_rmse: 0.9032 at epoch 177
# Epoch: 177, Loss: 0.7611, Train: 0.8719, Val: 0.9032
# Saving model with val_rmse: 0.9031 at epoch 178
# Epoch: 178, Loss: 0.7604, Train: 0.8715, Val: 0.9031
# Saving model with val_rmse: 0.9031 at epoch 179
# Epoch: 179, Loss: 0.7597, Train: 0.8711, Val: 0.9031
# Saving model with val_rmse: 0.9030 at epoch 180
# Epoch: 180, Loss: 0.7590, Train: 0.8707, Val: 0.9030
# Saving model with val_rmse: 0.9029 at epoch 181
# Epoch: 181, Loss: 0.7583, Train: 0.8703, Val: 0.9029
# Saving model with val_rmse: 0.9029 at epoch 182
# Epoch: 182, Loss: 0.7576, Train: 0.8699, Val: 0.9029
# Saving model with val_rmse: 0.9029 at epoch 183
# Epoch: 183, Loss: 0.7569, Train: 0.8695, Val: 0.9029
# Saving model with val_rmse: 0.9029 at epoch 184
# Epoch: 184, Loss: 0.7562, Train: 0.8691, Val: 0.9029
# Saving model with val_rmse: 0.9028 at epoch 185
# Epoch: 185, Loss: 0.7556, Train: 0.8688, Val: 0.9028
# Saving model with val_rmse: 0.9028 at epoch 186
# Epoch: 186, Loss: 0.7549, Train: 0.8684, Val: 0.9028
# Saving model with val_rmse: 0.9028 at epoch 187
# Epoch: 187, Loss: 0.7543, Train: 0.8680, Val: 0.9028
# Saving model with val_rmse: 0.9028 at epoch 188
# Epoch: 188, Loss: 0.7537, Train: 0.8677, Val: 0.9028
# Saving model with val_rmse: 0.9028 at epoch 189
# Epoch: 189, Loss: 0.7531, Train: 0.8673, Val: 0.9028
# Epoch: 190, Loss: 0.7525, Train: 0.8670, Val: 0.9028
# Epoch: 191, Loss: 0.7519, Train: 0.8667, Val: 0.9028
# Epoch: 192, Loss: 0.7513, Train: 0.8663, Val: 0.9028
# Epoch: 193, Loss: 0.7507, Train: 0.8660, Val: 0.9029
# Epoch: 194, Loss: 0.7502, Train: 0.8657, Val: 0.9029
# Epoch: 195, Loss: 0.7497, Train: 0.8654, Val: 0.9029
# Epoch: 196, Loss: 0.7491, Train: 0.8651, Val: 0.9029
# Epoch: 197, Loss: 0.7486, Train: 0.8648, Val: 0.9030
# Epoch: 198, Loss: 0.7481, Train: 0.8645, Val: 0.9030
# Epoch: 199, Loss: 0.7476, Train: 0.8642, Val: 0.9031
# Epoch: 200, Loss: 0.7472, Train: 0.8640, Val: 0.9031

# %%
print(f'Loading model with val_rmse: {best_val_rmse:.4f} at epoch {best_epoch}')
model.load_state_dict(torch.load(model_file_name))

print("Test rmse:", test(model, test_data))
# Out:
# Loading model with val_rmse: 0.9028 at epoch 189
# Test rmse: 0.9087042212486267
