# %%
# !pip install torch_scatter torch_sparse torch_cluster torch_spline_conv
# !pip install torch_geometric

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
import nltk
from nltk.corpus import stopwords
import scipy
import sklearn
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
from sklearn.preprocessing import OneHotEncoder
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

from tqdm.auto import tqdm
from timeit import default_timer as timer

from sklearn.utils import shuffle

from torch import nn, optim, Tensor

from torch_sparse import SparseTensor, matmul

from torch_geometric.utils import structured_negative_sampling
from torch_geometric.data import download_url, extract_zip
from torch_geometric.nn.conv.gcn_conv import gcn_norm
from torch_geometric.nn.conv import MessagePassing
from torch_geometric.typing import Adj

import warnings
warnings.filterwarnings("ignore")

# %%
# # If running in Colab
# from google.colab import drive
# drive.mount('/content/drive')

# %%
output_path = 'output/models/'

# %%
# ls

# %%
# cd drive/MyDrive/RecSys_KB/Aleksis

# %%
movies = pd.read_csv('ml-latest-small/movies.csv')
ratings = pd.read_csv('ml-latest-small/ratings.csv')

# %%
ratings
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres  \
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
#
#                                            abstracts  abstracts_count  \
# 0  Toy Story (1995) genres: Adventure|Animation|C...                0
# 1  Jumanji is a 1995 American fantasy adventure f...                1
# 2  Grumpier Old Men is a 1995 American romantic c...                1
# 3  Waiting to Exhale (1995) genres: Comedy|Drama|...                0
# 4  Father of the Bride Part II (1995) genres: Comedy                0
#
#                                  abstract_embeddings
# 0  [-3.30134444e-02 -2.01094374e-02  7.14708790e-...
# 1  [-1.18304212e-02  6.41161203e-02  9.13541857e-...
# 2  [-4.35247384e-02 -2.99240090e-02 -1.32443719e-...
# 3  [-6.43825084e-02 -6.76364526e-02 -1.91318002e-...
# 4  [-4.51376252e-02 -5.00504188e-02 -1.56385768e-...

# %%
ratings.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
print("Any null values in movies:\n" , movies.isnull().sum())
print("Any null values in ratings train:\n ", ratings.isnull().sum())
# Out:
# Any null values in movies:
#  movieId                0
# title                  0
# genres                 0
# abstracts              0
# abstracts_count        0
# abstract_embeddings    0
# dtype: int64
# Any null values in ratings train:
#   userId       0
# movieId      0
# rating       0
# timestamp    0
# dtype: int64

# %%
len(movies)
# Out:
# 9742

# %%
len(movies['title'].unique())
# Out:
# 9737

# %%
ratings['rating'].unique()
# Out:
# array([4. , 5. , 3. , 2. , 1. , 4.5, 3.5, 2.5, 0.5, 1.5])

# %%
ratings['rating'].value_counts(ascending=False)
# Out:
# rating
# 4.0    26818
# 3.0    20047
# 5.0    13211
# 3.5    13136
# 4.5     8551
# 2.0     7551
# 2.5     5550
# 1.0     2811
# 1.5     1791
# 0.5     1370
# Name: count, dtype: int64

# %%
ratings['userId'].value_counts(ascending=True)
# Out:
# userId
# 442      20
# 406      20
# 147      20
# 194      20
# 569      20
#        ...
# 274    1346
# 448    1864
# 474    2108
# 599    2478
# 414    2698
# Name: count, Length: 610, dtype: int64

# %%
ratings['movieId'].value_counts(ascending=True)
# Out:
# movieId
# 163981      1
# 142602      1
# 142961      1
# 5706        1
# 5468        1
#          ...
# 2571      278
# 593       279
# 296       307
# 318       317
# 356       329
# Name: count, Length: 9724, dtype: int64

# %%
movie_ratings_count = ratings['movieId'].value_counts(ascending=True)

# %%
sum(ratings['movieId'].value_counts(ascending=True) == 1)
# Out:
# 3446

# %%
# X_train, X_test, y_train, y_test = train_test_split(ratings[['userId', 'movieId']], ratings[['rating']], stratify=ratings[['rating']], test_size=0.20, random_state=42)
# X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, stratify=y_train, test_size=0.10, random_state=42)

# %%
X_train, X_test = train_test_split(ratings[['userId', 'movieId', 'rating']], stratify=ratings[['rating']], test_size=0.20, random_state=42)
X_train, X_val = train_test_split(X_train, stratify=X_train[['rating']], test_size=0.10, random_state=42)

# %%
# X_train, X_test = train_test_split(ratings[['userId', 'movieId', 'rating']], test_size=0.20, random_state=42)
# X_train, X_val = train_test_split(X_train, test_size=0.10, random_state=42)

# %%
# X_train, X_test, y_train, y_test = train_test_split(ratings[['userId', 'movieId']], ratings[['rating']], test_size=0.10, random_state=42)
# X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.10, random_state=42)

# %%
users_train = X_train.userId.unique()

# %%
users_train = X_train.userId.unique()
movies_train = X_train.movieId.unique()

# %%
movies_with_enough_ratings = list(filter(lambda x: movie_ratings_count[x] >= 0, movies_train))

# %%
len(movies_with_enough_ratings)
# Out:
# 8661

# %%
userid2idx = {o:i + 1 for i,o in enumerate(users_train)}
# userid2idx = {o:i + 1 for i,o in enumerate(ratings.userId.unique())}
# movieid2idx = {o:i + 1 for i,o in enumerate(movies_with_enough_ratings)}
movieid2idx = {o:i + 1 for i,o in enumerate(ratings.movieId.unique())}

# %%
userid2idx = {o:i for i,o in enumerate(users_train)}
# userid2idx = {o:i + 1 for i,o in enumerate(ratings.userId.unique())}
# movieid2idx = {o:i + 1 for i,o in enumerate(movies_with_enough_ratings)}
movieid2idx = {o:i for i,o in enumerate(ratings.movieId.unique())}

# %%
idx2userId= {v:k  for k,v in userid2idx.items()}
idx2movieId= {v:k  for k,v in movieid2idx.items()}

# %%
# userid2idx[-1] = 0 # unk user
# movieid2idx[-1] = 0 # unk movie

# %%
len(userid2idx), len(movieid2idx)
# Out:
# (610, 9724)

# %%
num_users, num_movies = len(userid2idx), len(movieid2idx)
num_users, num_movies
# Out:
# (610, 9724)

# %%
def get_index(data):
    data['userId'] = data['userId'].apply(lambda x: userid2idx.get(x, 0))
    data['movieId'] = data['movieId'].apply(lambda x: movieid2idx.get(x, 0))

# %%
movies
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres  \
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# 4                                          Comedy
# ...                                           ...
# 9737              Action|Animation|Comedy|Fantasy
# 9738                     Animation|Comedy|Fantasy
# 9739                                        Drama
# 9740                             Action|Animation
# 9741                                       Comedy
#
#                                               abstracts  abstracts_count  \
# 0     Toy Story (1995) genres: Adventure|Animation|C...                0
# 1     Jumanji is a 1995 American fantasy adventure f...                1
# 2     Grumpier Old Men is a 1995 American romantic c...                1
# 3     Waiting to Exhale (1995) genres: Comedy|Drama|...                0
# 4     Father of the Bride Part II (1995) genres: Comedy                0
# ...                                                 ...              ...
# 9737  The Butler Bulldogs men's basketball team repr...                2
# 9738  No Game No Life (Japanese: ノーゲーム・ノーライフ, Hepbur...                1
# 9739  Flint is a sedimentary cryptocrystalline form ...                1
# 9740  Bungo Stray Dogs (Japanese: 文豪ストレイドッグス, Hepbur...                2
# 9741  Andrew Dice Clay (born Andrew Clay Silverstein...                2
#
#                                     abstract_embeddings
# 0     [-3.30134444e-02 -2.01094374e-02  7.14708790e-...
# 1     [-1.18304212e-02  6.41161203e-02  9.13541857e-...
# 2     [-4.35247384e-02 -2.99240090e-02 -1.32443719e-...
# 3     [-6.43825084e-02 -6.76364526e-02 -1.91318002e-...
# 4     [-4.51376252e-02 -5.00504188e-02 -1.56385768e-...
# ...                                                 ...
# 9737  [ 3.13083529e-02  1.48075968e-02  3.68007384e-...
# 9738  [-1.92668010e-02 -4.74059843e-02 -8.06948766e-...
# 9739  [-5.53447567e-02 -1.97313577e-02  3.11960699e-...
# 9740  [-1.11603690e-03 -6.92510679e-02  1.85637157e-...
# 9741  [ 3.34916031e-03 -1.37352213e-01 -4.35352363e-...
#
# [9742 rows x 6 columns]

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %%
movies
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres  \
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# 4                                          Comedy
# ...                                           ...
# 9737              Action|Animation|Comedy|Fantasy
# 9738                     Animation|Comedy|Fantasy
# 9739                                        Drama
# 9740                             Action|Animation
# 9741                                       Comedy
#
#                                               abstracts  abstracts_count  \
# 0     Toy Story (1995) genres: Adventure|Animation|C...                0
# 1     Jumanji is a 1995 American fantasy adventure f...                1
# 2     Grumpier Old Men is a 1995 American romantic c...                1
# 3     Waiting to Exhale (1995) genres: Comedy|Drama|...                0
# 4     Father of the Bride Part II (1995) genres: Comedy                0
# ...                                                 ...              ...
# 9737  The Butler Bulldogs men's basketball team repr...                2
# 9738  No Game No Life (Japanese: ノーゲーム・ノーライフ, Hepbur...                1
# 9739  Flint is a sedimentary cryptocrystalline form ...                1
# 9740  Bungo Stray Dogs (Japanese: 文豪ストレイドッグス, Hepbur...                2
# 9741  Andrew Dice Clay (born Andrew Clay Silverstein...                2
#
#                                     abstract_embeddings
# 0     [-3.30134444e-02 -2.01094374e-02  7.14708790e-...
# 1     [-1.18304212e-02  6.41161203e-02  9.13541857e-...
# 2     [-4.35247384e-02 -2.99240090e-02 -1.32443719e-...
# 3     [-6.43825084e-02 -6.76364526e-02 -1.91318002e-...
# 4     [-4.51376252e-02 -5.00504188e-02 -1.56385768e-...
# ...                                                 ...
# 9737  [ 3.13083529e-02  1.48075968e-02  3.68007384e-...
# 9738  [-1.92668010e-02 -4.74059843e-02 -8.06948766e-...
# 9739  [-5.53447567e-02 -1.97313577e-02  3.11960699e-...
# 9740  [-1.11603690e-03 -6.92510679e-02  1.85637157e-...
# 9741  [ 3.34916031e-03 -1.37352213e-01 -4.35352363e-...
#
# [9742 rows x 6 columns]

# %%
# movie2genre_vec = {}
# for i, row in movies.iterrows():
#     movie2genre_vec[row['movieId']] = sum(le.transform(np.array(row['genres'].split('|')).reshape(-1, 1)).toarray())

# %%
# movie2genre_vec[1]

# %%
def get_edge_index(X): # , y):
    edge_index = [[], []]
    edge_values = []
    for i, row in X.iterrows():
        edge_index[0].append(userid2idx.get(row['userId'], 0))
        edge_index[1].append(movieid2idx.get(row['movieId'], 0))
        edge_values.append(row['rating'])

    return edge_index, edge_values #y['rating'].to_list()

# %%
# get_edge_index(X_train)

# %%
edge_index_train, edge_values_train = get_edge_index(X_train)
edge_index_val, edge_values_val     = get_edge_index(X_val)
edge_index_test, edge_values_test = get_edge_index(X_test)

# %%
len(edge_index_train[0]), len(edge_values_train)
# Out:
# (72601, 72601)

# %%
np.array(edge_index_train)[0]
# Out:
# array([ 0,  1,  2, ..., 57,  3, 38])

# %%
np.array(edge_index_train).shape
# Out:
# (2, 72601)

# %%
len(edge_index_train[0])
# Out:
# 72601

# %%
len(edge_index_train[0]) + len(edge_index_val[0]) + len(edge_index_test[0])
# Out:
# 100836

# %%
def convert_adj_mat_edge_index_to_r_mat_edge_index(input_edge_index, input_edge_values):

    sparse_input_edge_index = SparseTensor(row=input_edge_index[0],
                                           col=input_edge_index[1],
                                           value = input_edge_values,
                                           sparse_sizes=((num_users + num_movies), num_users + num_movies))

    adj_mat = sparse_input_edge_index.to_dense()
    interact_mat = adj_mat[: num_users, num_users :]

    r_mat_edge_index = interact_mat.to_sparse_coo().indices()
    r_mat_edge_values = interact_mat.to_sparse_coo().values()

    return r_mat_edge_index, r_mat_edge_values

# %%
torch.tensor(edge_index_train).shape
# Out:
# torch.Size([2, 72601])

# %%
def convert_r_mat_edge_index_to_adj_mat_edge_index(input_edge_index, input_edge_values):
    R = torch.zeros((num_users, num_movies))
    for i in range(len(input_edge_index[0])):
        row_idx = input_edge_index[0][i]
        col_idx = input_edge_index[1][i]
        R[row_idx][col_idx] = input_edge_values[i] # assign actual edge value to Interaction Matrix

    R_transpose = torch.transpose(R, 0, 1)

    # create adj_matrix
    adj_mat = torch.zeros((num_users + num_movies , num_users + num_movies))
    adj_mat[: num_users, num_users :] = R.clone()
    adj_mat[num_users :, : num_users] = R_transpose.clone()

    adj_mat_coo = adj_mat.to_sparse_coo()
    adj_mat_coo_indices = adj_mat_coo.indices()
    adj_mat_coo_values = adj_mat_coo.values()
    return adj_mat_coo_indices, adj_mat_coo_values

# %%
edge_index_train, edge_values_train = torch.tensor(edge_index_train), torch.tensor(edge_values_train)
edge_index_val,   edge_values_val   = torch.tensor(edge_index_val), torch.tensor(  edge_values_val)  
edge_index_test, edge_values_test   = torch.tensor(edge_index_test), torch.tensor(edge_values_test)

# %%
edge_index_train[1].max()
# Out:
# tensor(9722)

# %%
adj_edge_index_train, adj_edge_values_train  = convert_r_mat_edge_index_to_adj_mat_edge_index(  edge_index_train, edge_values_train)
adj_edge_index_val, adj_edge_values_val     = convert_r_mat_edge_index_to_adj_mat_edge_index(   edge_index_val,   edge_values_val  )
adj_edge_index_test, adj_edge_values_test   = convert_r_mat_edge_index_to_adj_mat_edge_index(   edge_index_test, edge_values_test  )

# %%
adj_edge_index_train.shape
# Out:
# torch.Size([2, 145202])

# %%
r_mat_edge_index_train, r_mat_edge_values_train   = convert_adj_mat_edge_index_to_r_mat_edge_index(adj_edge_index_train, adj_edge_values_train)
r_mat_edge_index_val,   r_mat_edge_values_val     = convert_adj_mat_edge_index_to_r_mat_edge_index(adj_edge_index_val, adj_edge_values_val    )
r_mat_edge_index_test,  r_mat_edge_values_test    = convert_adj_mat_edge_index_to_r_mat_edge_index(adj_edge_index_test, adj_edge_values_test  )

# %%
r_mat_edge_index_train.shape
# Out:
# torch.Size([2, 72601])

# %%
movie2abstract_embed = {}

# %%
import pickle
with open('movie2abstract_embed.pickle', 'rb') as f:
    movie2abstract_embed = pickle.load(f)

# %%
def get_abstract_embeddings(movies: torch.tensor):
    result = []

    for movie in movies:
        movieId = idx2movieId[movie.item()]
        result.append(movie2abstract_embed[movieId])
    return torch.tensor(result)

# %%
abstract_embeddings_train = get_abstract_embeddings(r_mat_edge_index_train[0, :])
abstract_embeddings_val = get_abstract_embeddings(r_mat_edge_index_val[0, :])
abstract_embeddings_test = get_abstract_embeddings(r_mat_edge_index_test[0, :])

# %%
def train_step(model,
               edge_index_train,
               r_mat_edge_index_train,
               r_mat_edge_values_train,
               abstract_embeddings_train,
               loss_fn,
               optimizer,
               device):

    model.train()
    y_pred = model(edge_index_train, r_mat_edge_index_train, abstract_embeddings_train)

    loss = loss_fn(y_pred, r_mat_edge_values_train.view(-1, 1))
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    return loss.item()

def test_step(model,
              edge_index_test,
              r_mat_edge_index_test,
              r_mat_edge_values_test,
              abstract_embeddings_test,
              loss_fn,
              device):
    model.eval()

    with torch.inference_mode():

        y_pred = model(edge_index_test, r_mat_edge_index_test, abstract_embeddings_test)

        loss = loss_fn(y_pred, r_mat_edge_values_test.view(-1, 1))

        return loss.item()

def train(model,
          optimizer,
          loss_fn,
          epochs,
          device,
          scheduler,
          edge_index_train=adj_edge_index_train,
          r_mat_edge_index_train=r_mat_edge_index_train,
          r_mat_edge_values_train=r_mat_edge_values_train,
          abstract_embeddings_train=abstract_embeddings_train,
          edge_index_test=adj_edge_index_val,
          r_mat_edge_index_test=r_mat_edge_index_val,
          r_mat_edge_values_test=r_mat_edge_values_val,
          abstract_embeddings_test=abstract_embeddings_val,
          results = {"train_loss": [],
               "test_loss": [],
    }
):
    model.to(device)

    best_loss = float('inf')

    edge_index_train = edge_index_train.to(device)
    r_mat_edge_index_train = r_mat_edge_index_train.to(device)
    r_mat_edge_values_train = r_mat_edge_values_train.float().to(device)
    abstract_embeddings_train = abstract_embeddings_train.to(device)
    edge_index_test = edge_index_test.to(device)
    r_mat_edge_index_test = r_mat_edge_index_test.to(device)
    r_mat_edge_values_test = r_mat_edge_values_test.float().to(device)
    abstract_embeddings_test = abstract_embeddings_test.to(device)

    for epoch in tqdm(range(epochs)):

        start_time = timer()
        train_loss = train_step(model=model,
                                edge_index_train=edge_index_train,
                                r_mat_edge_index_train=r_mat_edge_index_train,
                                r_mat_edge_values_train=r_mat_edge_values_train,
                                abstract_embeddings_train=abstract_embeddings_train,
                                loss_fn=loss_fn,
                                optimizer=optimizer,
                                device=device)
        end_time = timer()
        test_loss = test_step(model=model,
                              edge_index_test=edge_index_test,
                              r_mat_edge_index_test=r_mat_edge_index_test,
                              r_mat_edge_values_test=r_mat_edge_values_test,
                              abstract_embeddings_test=abstract_embeddings_test,
                              loss_fn=loss_fn,
                              device=device)

        results["train_loss"].append(train_loss)
        results["test_loss"].append(test_loss)

        if epoch % 200 == 0 and epoch != 0:
            scheduler.step()

            if best_loss > test_loss:
                best_loss = test_loss
                print('Saving new best model.')
                model.save( output_path + model.name + ".pt")



            print(
              f"Epoch: {epoch} | "
              f"train_loss: {train_loss:.4f} | "
              f"train RMSE: {np.sqrt(train_loss):.4f} | "
              f"test_loss: {test_loss:.4f} | "
              f"test RMSE: {np.sqrt(test_loss):.4f} | "
              f"time: {(end_time-start_time):.4f} "
              f"Learning rate: {next(iter(scheduler.optimizer.param_groups))['lr']}"
            )

    return results

def plot_loss_curves(results):

    loss = results["train_loss"]
    test_loss = results["test_loss"]

    epochs = range(len(results["train_loss"]))

    plt.figure(figsize=(15, 7))

    # Plot loss
    plt.subplot(1, 2, 1)
    plt.plot(epochs, loss, label="train_loss")
    plt.plot(epochs, test_loss, label="test_loss")
    plt.title("Loss")
    plt.xlabel("Epochs")
    plt.legend()

# %%
adj_edge_index_train.shape, r_mat_edge_index_train.shape, r_mat_edge_values_train.shape
# Out:
# (torch.Size([2, 145202]), torch.Size([2, 72601]), torch.Size([72601]))

# %%
adj_edge_index_train, r_mat_edge_index_train, r_mat_edge_values_train
# Out:
# (tensor([[    0,     0,     0,  ..., 10329, 10330, 10332],
#          [  610,   614,   617,  ...,    13,    13,    13]]),
#  tensor([[   0,    0,    0,  ...,  609,  609,  609],
#          [   0,    4,    7,  ...,  902,  915, 1925]]),
#  tensor([3.0000, 4.5000, 4.0000,  ..., 4.5000, 4.5000, 4.0000]))

# %%
# edge_index_train=edge_index_train,
#           adj_edge_index_train=adj_edge_index_train,
#           adj_edge_values_train=adj_edge_values_train,
#           edge_index_test=edge_index_test,
#           adj_edge_index_test=adj_edge_index_test,
#           adj_edge_values_test=adj_edge_values_test,

# %%
# defines LightGCN model
class LightGCN(MessagePassing):

    def save(self, fileName):
        torch.save(self.state_dict(), fileName)

    def load(self, fileName, device):
        self.load_state_dict(torch.load(fileName, map_location=device))

    def __init__(self, num_users, num_items, embedding_dim=64, abstract_embedding_dim=384, K=3, add_self_loops=False, dropout_rate=0.1, name='name'):

        super().__init__()
        self.dropout_rate = dropout_rate
        self.num_users = num_users
        self.num_items = num_items
        self.embedding_dim = embedding_dim
        self.K = K
        self.add_self_loops = add_self_loops
        self.name = name
        self.abstract_embedding_dim = abstract_embedding_dim
        self.drop1 = nn.Dropout(dropout_rate)

        # define user and item embedding for direct look up.
        # embedding dimension: num_user/num_item x embedding_dim
        self.users_emb = nn.Embedding(num_embeddings=self.num_users, embedding_dim=self.embedding_dim) # e_u^0

        self.items_emb = nn.Embedding(num_embeddings=self.num_items, embedding_dim=self.embedding_dim) # e_i^0


        # "Fills the input Tensor with values drawn from the normal distribution"
        # according to LightGCN paper, this gives better performance
        nn.init.normal_(self.users_emb.weight, std=0.1)
        nn.init.normal_(self.items_emb.weight, std=0.1)

        # create a linear layer (fully connected layer) so we can output a single value (predicted_rating)
        self.out = nn.Linear(embedding_dim * 2 + abstract_embedding_dim, 1)

    def forward(self, edge_index, r_mat_edge_index, abstract_embeddings):
        edge_index_norm = gcn_norm(edge_index=edge_index,
                                   add_self_loops=self.add_self_loops)

        # concat the user_emb and item_emb as the layer0 embing matrix
        # size will be (n_users + n_items) x emb_vector_len.   e.g: 10334 x 64
        emb_0 = torch.cat([self.users_emb.weight, self.items_emb.weight]) # E^0

        embs = [emb_0] # save the layer0 emb to the embs list

        # emb_k is the emb that we are actually going to push it through the graph layers
        # as described in lightGCN paper formula 7
        emb_k = emb_0

        # push the embedding of all users and items through the Graph Model K times.
        # K here is the number of layers
        for i in range(self.K):
            emb_k = self.propagate(edge_index=edge_index_norm[0], x=emb_k, norm=edge_index_norm[1])
            embs.append(emb_k)


        # this is doing the formula8 in LightGCN paper

        # the stacked embs is a list of embedding matrix at each layer
        #    it's of shape n_nodes x (n_layers + 1) x emb_vector_len.
        #        e.g: torch.Size([10334, 4, 64])
        embs = torch.stack(embs, dim=1)

        # From LightGCn paper: "In our experiments, we find that setting α_k uniformly as 1/(K + 1)
        #    leads to good performance in general."
        emb_final = torch.mean(embs, dim=1) # E^K

        users_emb_final, items_emb_final = torch.split(emb_final,
                                                       [self.num_users, self.num_items]) # splits into e_u^K and e_i^K

        src, dest =  r_mat_edge_index[0], r_mat_edge_index[1]

        # applying embedding lookup to get embeddings for src nodes and dest nodes in the edge list
        user_embeds = users_emb_final[src]
        item_embeds = items_emb_final[dest]

        # output dim: edge_index_len x 128 (given 64 is the original emb_vector_len)
        # print(user_embeds.shape, item_embeds.shape, abstract_embeddings.shape)
        x = torch.cat([user_embeds, item_embeds, abstract_embeddings], dim=1)

        x = self.drop1(x)

        # push it through the linear layer
        output = self.out(x)

        return output

    def message(self, x_j, norm):
        return norm.view(-1, 1) * x_j

# %%
class RMSELoss(nn.Module):
    def __init__(self):
        super().__init__()
        self.mse = nn.MSELoss()

    def forward(self, yhat, y):
        return torch.sqrt(self.mse(yhat ,y))

# %%
model = LightGCN(num_users=num_users, num_items=num_movies, embedding_dim=64, K=1, add_self_loops=True, dropout_rate=0.5, name="light_gcn_with_abs_emb") # best 0.9504
loss = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3, weight_decay=0.01)
scheduler = optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.95)
# scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=1, threshold=0.0001, threshold_mode='rel')

# %%
results = train(model=model, 
          optimizer = optimizer,
          loss_fn = nn.MSELoss(),                       
          epochs = 10_000,
          device = device,
          scheduler=scheduler)
plot_loss_curves(results)
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
# Saving new best model.
# Epoch: 200 | train_loss: 2.0725 | train RMSE: 1.4396 | test_loss: 2.0975 | test RMSE: 1.4483 | time: 0.0096 Learning rate: 0.00095
# Saving new best model.
# Epoch: 400 | train_loss: 1.4079 | train RMSE: 1.1866 | test_loss: 1.3799 | test RMSE: 1.1747 | time: 0.0099 Learning rate: 0.0009025
# Saving new best model.
# Epoch: 600 | train_loss: 1.2342 | train RMSE: 1.1109 | test_loss: 1.1879 | test RMSE: 1.0899 | time: 0.0100 Learning rate: 0.000857375
# Saving new best model.
# Epoch: 800 | train_loss: 1.1516 | train RMSE: 1.0731 | test_loss: 1.0944 | test RMSE: 1.0461 | time: 0.0097 Learning rate: 0.0008145062499999999
# Saving new best model.
# Epoch: 1000 | train_loss: 1.1019 | train RMSE: 1.0497 | test_loss: 1.0398 | test RMSE: 1.0197 | time: 0.0100 Learning rate: 0.0007737809374999998
# Saving new best model.
# Epoch: 1200 | train_loss: 1.0630 | train RMSE: 1.0310 | test_loss: 1.0033 | test RMSE: 1.0016 | time: 0.0133 Learning rate: 0.0007350918906249997
# Saving new best model.
# Epoch: 1400 | train_loss: 1.0418 | train RMSE: 1.0207 | test_loss: 0.9776 | test RMSE: 0.9888 | time: 0.0139 Learning rate: 0.0006983372960937497
# Saving new best model.
# Epoch: 1600 | train_loss: 1.0221 | train RMSE: 1.0110 | test_loss: 0.9590 | test RMSE: 0.9793 | time: 0.0128 Learning rate: 0.0006634204312890621
# Saving new best model.
# Epoch: 1800 | train_loss: 1.0067 | train RMSE: 1.0034 | test_loss: 0.9450 | test RMSE: 0.9721 | time: 0.0115 Learning rate: 0.000630249409724609
# Saving new best model.
# Epoch: 2000 | train_loss: 0.9954 | train RMSE: 0.9977 | test_loss: 0.9335 | test RMSE: 0.9662 | time: 0.0121 Learning rate: 0.0005987369392383785
# Saving new best model.
# Epoch: 2200 | train_loss: 0.9795 | train RMSE: 0.9897 | test_loss: 0.9240 | test RMSE: 0.9613 | time: 0.0126 Learning rate: 0.0005688000922764595
# Saving new best model.
# Epoch: 2400 | train_loss: 0.9744 | train RMSE: 0.9871 | test_loss: 0.9169 | test RMSE: 0.9576 | time: 0.0124 Learning rate: 0.0005403600876626365
# Saving new best model.
# Epoch: 2600 | train_loss: 0.9662 | train RMSE: 0.9830 | test_loss: 0.9106 | test RMSE: 0.9542 | time: 0.0114 Learning rate: 0.0005133420832795047
# Saving new best model.
# Epoch: 2800 | train_loss: 0.9576 | train RMSE: 0.9786 | test_loss: 0.9053 | test RMSE: 0.9514 | time: 0.0101 Learning rate: 0.00048767497911552944
# Saving new best model.
# Epoch: 9800 | train_loss: 0.8949 | train RMSE: 0.9460 | test_loss: 0.8749 | test RMSE: 0.9354 | time: 0.0118 Learning rate: 8.099471081759274e-05

# %%
# defines LightGCN model
class DeepLightGCN(MessagePassing):

    def save(self, fileName):
        torch.save(self.state_dict(), fileName)

    def load(self, fileName, device):
        self.load_state_dict(torch.load(fileName, map_location=device))

    def __init__(self, num_users, num_items, embedding_dim=64, K=3, abstract_embedding_dim=384, n_hidden=32, add_self_loops=False, dropout_rate=0.1, name='name'):

        super().__init__()
        self.dropout_rate = dropout_rate
        self.num_users = num_users
        self.num_items = num_items
        self.embedding_dim = embedding_dim
        self.K = K
        self.add_self_loops = add_self_loops
        self.name = name
        self.drop1 = nn.Dropout(dropout_rate)
        self.drop2 = nn.Dropout(dropout_rate)
        self.abstract_embedding_dim = abstract_embedding_dim

        # define user and item embedding for direct look up.
        # embedding dimension: num_user/num_item x embedding_dim
        self.users_emb = nn.Embedding(num_embeddings=self.num_users, embedding_dim=self.embedding_dim) # e_u^0

        self.items_emb = nn.Embedding(num_embeddings=self.num_items, embedding_dim=self.embedding_dim) # e_i^0


        # "Fills the input Tensor with values drawn from the normal distribution"
        # according to LightGCN paper, this gives better performance
        nn.init.normal_(self.users_emb.weight, std=0.1)
        nn.init.normal_(self.items_emb.weight, std=0.1)

        self.lin1 = nn.Linear(embedding_dim*2 + abstract_embedding_dim, n_hidden)
        # create a linear layer (fully connected layer) so we can output a single value (predicted_rating)
        self.out = nn.Linear(n_hidden, 1)

    def forward(self, edge_index, r_mat_edge_index, abstract_embeddings):
        edge_index_norm = gcn_norm(edge_index=edge_index,
                                   add_self_loops=self.add_self_loops)

        # concat the user_emb and item_emb as the layer0 embing matrix
        # size will be (n_users + n_items) x emb_vector_len.   e.g: 10334 x 64
        emb_0 = torch.cat([self.users_emb.weight, self.items_emb.weight]) # E^0

        embs = [emb_0] # save the layer0 emb to the embs list

        # emb_k is the emb that we are actually going to push it through the graph layers
        # as described in lightGCN paper formula 7
        emb_k = emb_0

        # push the embedding of all users and items through the Graph Model K times.
        # K here is the number of layers
        for i in range(self.K):
            emb_k = self.propagate(edge_index=edge_index_norm[0], x=emb_k, norm=edge_index_norm[1])
            embs.append(emb_k)


        # this is doing the formula8 in LightGCN paper

        # the stacked embs is a list of embedding matrix at each layer
        #    it's of shape n_nodes x (n_layers + 1) x emb_vector_len.
        #        e.g: torch.Size([10334, 4, 64])
        embs = torch.stack(embs, dim=1)

        # From LightGCn paper: "In our experiments, we find that setting α_k uniformly as 1/(K + 1)
        #    leads to good performance in general."
        emb_final = torch.mean(embs, dim=1) # E^K

        users_emb_final, items_emb_final = torch.split(emb_final,
                                                       [self.num_users, self.num_items]) # splits into e_u^K and e_i^K

        src, dest =  r_mat_edge_index[0], r_mat_edge_index[1]

        # applying embedding lookup to get embeddings for src nodes and dest nodes in the edge list
        user_embeds = users_emb_final[src]
        item_embeds = items_emb_final[dest]

        # output dim: edge_index_len x 128 (given 64 is the original emb_vector_len)
        x = torch.cat([user_embeds, item_embeds, abstract_embeddings], dim=1)

        x = self.drop1(x)

        x = self.lin1(x)

        x = self.drop2(x)
        # push it through the linear layer
        output = self.out(x)

        return output

    def message(self, x_j, norm):
        return norm.view(-1, 1) * x_j

# %%
model = DeepLightGCN(num_users=num_users, num_items=num_movies, embedding_dim=128, K=1, n_hidden=128, add_self_loops=True, dropout_rate=0.5, name="light_gcn_with_abs_emb_v2") # best 0.9504
loss = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3, weight_decay=0.01)
scheduler = optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.95)
# scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=1, threshold=0.0001, threshold_mode='rel')

# %%
results = train(model=model, #  test_loss: 0.7685 | test RMSE: 0.8767
          optimizer = optimizer,
          loss_fn = nn.MSELoss(),                              
          epochs = 10_000,
          device = device,
          scheduler=scheduler)
plot_loss_curves(results)
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
# Saving new best model.
# Epoch: 200 | train_loss: 1.0297 | train RMSE: 1.0147 | test_loss: 0.8739 | test RMSE: 0.9348 | time: 0.0208 Learning rate: 0.00095
# Saving new best model.
# Epoch: 400 | train_loss: 0.9155 | train RMSE: 0.9568 | test_loss: 0.8218 | test RMSE: 0.9065 | time: 0.0212 Learning rate: 0.0009025
# Saving new best model.
# Epoch: 600 | train_loss: 0.8843 | train RMSE: 0.9404 | test_loss: 0.8081 | test RMSE: 0.8990 | time: 0.0212 Learning rate: 0.000857375
# Saving new best model.
# Epoch: 800 | train_loss: 0.8743 | train RMSE: 0.9350 | test_loss: 0.8030 | test RMSE: 0.8961 | time: 0.0251 Learning rate: 0.0008145062499999999
# Saving new best model.
# Epoch: 1000 | train_loss: 0.8674 | train RMSE: 0.9313 | test_loss: 0.7971 | test RMSE: 0.8928 | time: 0.0217 Learning rate: 0.0007737809374999998
# Saving new best model.
# Epoch: 1200 | train_loss: 0.8559 | train RMSE: 0.9251 | test_loss: 0.7922 | test RMSE: 0.8900 | time: 0.0240 Learning rate: 0.0007350918906249997
# Saving new best model.
# Epoch: 1400 | train_loss: 0.8461 | train RMSE: 0.9198 | test_loss: 0.7861 | test RMSE: 0.8866 | time: 0.0234 Learning rate: 0.0006983372960937497
# Saving new best model.
# Epoch: 1600 | train_loss: 0.8355 | train RMSE: 0.9141 | test_loss: 0.7812 | test RMSE: 0.8838 | time: 0.0226 Learning rate: 0.0006634204312890621
# Saving new best model.
# Epoch: 1800 | train_loss: 0.8295 | train RMSE: 0.9108 | test_loss: 0.7781 | test RMSE: 0.8821 | time: 0.0236 Learning rate: 0.000630249409724609
# Saving new best model.
# Epoch: 2000 | train_loss: 0.8233 | train RMSE: 0.9074 | test_loss: 0.7745 | test RMSE: 0.8800 | time: 0.0231 Learning rate: 0.0005987369392383785
# Saving new best model.
# Epoch: 2200 | train_loss: 0.8170 | train RMSE: 0.9039 | test_loss: 0.7716 | test RMSE: 0.8784 | time: 0.0209 Learning rate: 0.0005688000922764595
# Saving new best model.
# Epoch: 2400 | train_loss: 0.8111 | train RMSE: 0.9006 | test_loss: 0.7699 | test RMSE: 0.8775 | time: 0.0222 Learning rate: 0.0005403600876626365
# Saving new best model.
# Epoch: 2600 | train_loss: 0.8117 | train RMSE: 0.9009 | test_loss: 0.7688 | test RMSE: 0.8768 | time: 0.0212 Learning rate: 0.0005133420832795047
# Saving new best model.
# Epoch: 2800 | train_loss: 0.8016 | train RMSE: 0.8953 | test_loss: 0.7668 | test RMSE: 0.8757 | time: 0.0207 Learning rate: 0.00048767497911552944
# %%
# defines LightGCN model
class DeepLightGCN_2(MessagePassing):

    def save(self, fileName):
        torch.save(self.state_dict(), fileName)

    def load(self, fileName, device):
        self.load_state_dict(torch.load(fileName, map_location=device))

    def __init__(self, num_users, num_items, embedding_dim=64, K=3, abstract_embedding_dim=384, n_hidden=32, add_self_loops=False, dropout_rate=0.1, name='name'):

        super().__init__()
        self.dropout_rate = dropout_rate
        self.num_users = num_users
        self.num_items = num_items
        self.embedding_dim = embedding_dim
        self.K = K
        self.add_self_loops = add_self_loops
        self.name = name
        self.drop1 = nn.Dropout(dropout_rate)
        self.drop2 = nn.Dropout(dropout_rate)
        self.abstract_embedding_dim = abstract_embedding_dim

        # define user and item embedding for direct look up.
        # embedding dimension: num_user/num_item x embedding_dim
        self.users_emb = nn.Embedding(num_embeddings=self.num_users, embedding_dim=self.embedding_dim) # e_u^0

        self.items_emb = nn.Embedding(num_embeddings=self.num_items, embedding_dim=self.embedding_dim) # e_i^0


        # "Fills the input Tensor with values drawn from the normal distribution"
        # according to LightGCN paper, this gives better performance
        nn.init.normal_(self.users_emb.weight, std=0.1)
        nn.init.normal_(self.items_emb.weight, std=0.1)

        self.lin1 = nn.Linear(embedding_dim*2 + abstract_embedding_dim, n_hidden)
        # create a linear layer (fully connected layer) so we can output a single value (predicted_rating)
        self.out = nn.Linear(n_hidden, 1)

    def forward(self, edge_index, r_mat_edge_index, abstract_embeddings):
        edge_index_norm = gcn_norm(edge_index=edge_index,
                                   add_self_loops=self.add_self_loops)

        # concat the user_emb and item_emb as the layer0 embing matrix
        # size will be (n_users + n_items) x emb_vector_len.   e.g: 10334 x 64
        items_emb = torch.cat(self.items_emb.weight, abstract_embeddings, dim=1)
        emb_0 = torch.cat([self.users_emb.weight, items_emb]) # E^0

        embs = [emb_0] # save the layer0 emb to the embs list

        # emb_k is the emb that we are actually going to push it through the graph layers
        # as described in lightGCN paper formula 7
        emb_k = emb_0

        # push the embedding of all users and items through the Graph Model K times.
        # K here is the number of layers
        for i in range(self.K):
            emb_k = self.propagate(edge_index=edge_index_norm[0], x=emb_k, norm=edge_index_norm[1])
            embs.append(emb_k)


        # this is doing the formula8 in LightGCN paper

        # the stacked embs is a list of embedding matrix at each layer
        #    it's of shape n_nodes x (n_layers + 1) x emb_vector_len.
        #        e.g: torch.Size([10334, 4, 64])
        embs = torch.stack(embs, dim=1)

        # From LightGCn paper: "In our experiments, we find that setting α_k uniformly as 1/(K + 1)
        #    leads to good performance in general."
        emb_final = torch.mean(embs, dim=1) # E^K

        users_emb_final, items_emb_final = torch.split(emb_final,
                                                       [self.num_users, self.num_items]) # splits into e_u^K and e_i^K

        src, dest =  r_mat_edge_index[0], r_mat_edge_index[1]

        # applying embedding lookup to get embeddings for src nodes and dest nodes in the edge list
        user_embeds = users_emb_final[src]
        item_embeds = items_emb_final[dest]

        # output dim: edge_index_len x 128 (given 64 is the original emb_vector_len)
        x = torch.cat([user_embeds, item_embeds], dim=1)

        x = self.drop1(x)

        x = self.lin1(x)

        x = self.drop2(x)
        # push it through the linear layer
        output = self.out(x)

        return output

    def message(self, x_j, norm):
        return norm.view(-1, 1) * x_j

# %%
model = DeepLightGCN(num_users=num_users, num_items=num_movies, embedding_dim=128, K=1, n_hidden=128, add_self_loops=True, dropout_rate=0.5, name="light_gcn_with_abs_emb_v3") # best 0.9504
loss = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3, weight_decay=0.01)
scheduler = optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.95)
# scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=1, threshold=0.0001, threshold_mode='rel')

# %%
results = train(model=model, #   test_loss: 0.7706 | test RMSE: 0.8778 
          optimizer = optimizer,
          loss_fn = nn.MSELoss(),
          epochs = 10_000,
          device = device,
          scheduler=scheduler)
plot_loss_curves(results)
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
# Saving new best model.
# Epoch: 200 | train_loss: 1.0439 | train RMSE: 1.0217 | test_loss: 0.8737 | test RMSE: 0.9347 | time: 0.0216 Learning rate: 0.00095
# Saving new best model.
# Epoch: 400 | train_loss: 0.9212 | train RMSE: 0.9598 | test_loss: 0.8217 | test RMSE: 0.9065 | time: 0.0192 Learning rate: 0.0009025
# Saving new best model.
# Epoch: 600 | train_loss: 0.8878 | train RMSE: 0.9422 | test_loss: 0.8088 | test RMSE: 0.8993 | time: 0.0197 Learning rate: 0.000857375
# Saving new best model.
# Epoch: 800 | train_loss: 0.8778 | train RMSE: 0.9369 | test_loss: 0.8028 | test RMSE: 0.8960 | time: 0.0195 Learning rate: 0.0008145062499999999
# Saving new best model.
# Epoch: 1000 | train_loss: 0.8691 | train RMSE: 0.9322 | test_loss: 0.7978 | test RMSE: 0.8932 | time: 0.0180 Learning rate: 0.0007737809374999998
# Saving new best model.
# Epoch: 1200 | train_loss: 0.8646 | train RMSE: 0.9298 | test_loss: 0.7925 | test RMSE: 0.8902 | time: 0.0181 Learning rate: 0.0007350918906249997
# Saving new best model.
# Epoch: 1400 | train_loss: 0.8508 | train RMSE: 0.9224 | test_loss: 0.7873 | test RMSE: 0.8873 | time: 0.0225 Learning rate: 0.0006983372960937497
# Saving new best model.
# Epoch: 1600 | train_loss: 0.8456 | train RMSE: 0.9195 | test_loss: 0.7833 | test RMSE: 0.8850 | time: 0.0205 Learning rate: 0.0006634204312890621
# Saving new best model.
# Epoch: 1800 | train_loss: 0.8346 | train RMSE: 0.9136 | test_loss: 0.7787 | test RMSE: 0.8824 | time: 0.0231 Learning rate: 0.000630249409724609
# Saving new best model.
# Epoch: 2000 | train_loss: 0.8278 | train RMSE: 0.9099 | test_loss: 0.7763 | test RMSE: 0.8811 | time: 0.0216 Learning rate: 0.0005987369392383785
# Saving new best model.
# Epoch: 2200 | train_loss: 0.8259 | train RMSE: 0.9088 | test_loss: 0.7731 | test RMSE: 0.8792 | time: 0.0207 Learning rate: 0.0005688000922764595
# Saving new best model.
# Epoch: 2400 | train_loss: 0.8159 | train RMSE: 0.9033 | test_loss: 0.7704 | test RMSE: 0.8777 | time: 0.0198 Learning rate: 0.0005403600876626365
# Saving new best model.
# Epoch: 2600 | train_loss: 0.8148 | train RMSE: 0.9026 | test_loss: 0.7691 | test RMSE: 0.8770 | time: 0.0208 Learning rate: 0.0005133420832795047
# Saving new best model.
# Epoch: 2800 | train_loss: 0.8094 | train RMSE: 0.8997 | test_loss: 0.7670 | test RMSE: 0.8758 | time: 0.0216 Learning rate: 0.00048767497911552944
# Saving new best model.
