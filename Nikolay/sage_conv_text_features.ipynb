# %%
import torch
import torch.nn.functional as F
from torch_geometric.nn import SAGEConv, to_hetero
from torch_geometric.data import HeteroData
import torch_geometric.transforms as T
from sentence_transformers import SentenceTransformer
from sklearn.model_selection import train_test_split
import pandas as pd

from IPython import get_ipython # type: ignore
import os

torch.manual_seed(0)

# get the notebook name
ip = get_ipython()
path = None
if '__vsc_ipynb_file__' in ip.user_ns: # type: ignore
    path = ip.user_ns['__vsc_ipynb_file__'] # type: ignore

os.makedirs('models/', exist_ok=True)
model_file_name = f"models/{os.path.basename(path)[:-6]}.pt" # type: ignore

# %% [markdown]
# Data

# %%
movie_path = 'dataset/ml-latest-small/movies_with_wikidata_values.csv'
rating_path = 'dataset/ml-latest-small/ratings.csv'

ratings_df = pd.read_csv(rating_path)[["userId", "movieId", "rating"]]
movies_df = pd.read_csv(movie_path, index_col='movieId')

# %%
# One-hot encode the genres:
genres = movies_df['genres'].str.get_dummies('|').values
genres = torch.from_numpy(
    genres
    ).to(torch.float)

years = torch.nan_to_num(torch.from_numpy(
    movies_df['year'].values
    ).to(torch.float), nan=1990).unsqueeze(1)
box_office = torch.nan_to_num(torch.from_numpy(
    movies_df['boxOfficeWorldwide'].map(lambda x: x/1000000).values
    ).to(torch.float), nan=0).unsqueeze(1)
score = torch.from_numpy(
    movies_df['tommatometerScore'].map(lambda x: int(x[:-1] if isinstance(x, str) and len(x) > 1 else 50)).values
    ).to(torch.float).unsqueeze(1)
duration = torch.nan_to_num(torch.from_numpy(
    movies_df['duration'].values
    ).to(torch.float), nan=70).unsqueeze(1)

# Load the pre-trained sentence transformer model and encode the movie titles:
model = SentenceTransformer('all-MiniLM-L6-v2')
with torch.no_grad():
    titles = model.encode(movies_df['title'].tolist(), convert_to_tensor=True, show_progress_bar=True)
    titles = titles.cpu()

# Concatenate the genres and title features:
movie_features = torch.cat([genres, titles], dim=-1)
user_ids_tensor = torch.LongTensor(range(len(ratings_df['userId'].unique())))
# Out:
# Batches:   0%|          | 0/305 [00:00<?, ?it/s]

# %%
unique_user_id = ratings_df['userId'].unique()
unique_user_id = pd.DataFrame(data={
    'userId': unique_user_id,
    'mappedUserId': pd.RangeIndex(len(unique_user_id))
    })

# Create a mapping from the movieId to a unique consecutive value in the range [0, num_movies]:
unique_movie_id = ratings_df['movieId'].unique()
unique_movie_id = pd.DataFrame(data={
    'movieId': unique_movie_id,
    'mappedMovieId': pd.RangeIndex(len(unique_movie_id))
    })

# Merge the mappings with the original data frame:
ratings_df = ratings_df.merge(unique_user_id, on='userId')
ratings_df = ratings_df.merge(unique_movie_id, on='movieId')

ratings_df_train, ratings_df_test = train_test_split(ratings_df, test_size=0.2, random_state=42)
ratings_df_test, ratings_df_val = train_test_split(ratings_df_test, test_size=0.5, random_state=42)

# %%
def create_data(ratings_df):
    edge_index = torch.stack([
    torch.tensor(ratings_df['mappedUserId'].values),
    torch.tensor(ratings_df['mappedMovieId'].values)]
    , dim=0)

    assert edge_index.shape == (2, len(ratings_df))
    data = HeteroData()
    # Add the user nodes:
    data['user'].x = user_ids_tensor  # [num_users, num_features_users]
    # Add the movie nodes:
    data['movie'].x = movie_features  # [num_movies, num_features_movies]
    # Add the rating edges:
    data['user', 'rates', 'movie'].edge_index = edge_index  # [2, num_ratings]
    # Add the rating labels:
    rating = torch.from_numpy(ratings_df['rating'].values).to(torch.float)
    data['user', 'rates', 'movie'].edge_label = rating  # [num_ratings]

    # We also need to make sure to add the reverse edges from movies to users
    # in order to let a GNN be able to pass messages in both directions.
    # We can leverage the `T.ToUndirected()` transform for this from PyG:
    data = T.ToUndirected()(data)

    # With the above transformation we also got reversed labels for the edges.
    # We are going to remove them:
    del data['movie', 'rev_rates', 'user'].edge_label

    assert data['user'].num_nodes == len(unique_user_id)
    assert data['user', 'rates', 'movie'].num_edges == len(ratings_df)

    return data

# %%
train_data, val_data, test_data = create_data(ratings_df_train), create_data(ratings_df_val), create_data(ratings_df_test)

# %%
class GraphEmbedding(torch.nn.Module):
    def __init__(self, num_users, user_embedding_dim):
        super().__init__()
        self.user_embedding = torch.nn.Embedding(num_users, user_embedding_dim)

    def forward(self, x_dict):
        x_dict['user'] = self.user_embedding(x_dict['user'])
        return x_dict

class GNNEncoder(torch.nn.Module):
    def __init__(self, hidden_channels, out_channels):
        super().__init__()
        self.conv1 = SAGEConv((-1, -1), hidden_channels)
        self.conv2 = SAGEConv((-1, -1), out_channels)

    def forward(self, x, edge_index):
        x = self.conv1(x, edge_index).relu()
        x = self.conv2(x, edge_index)
        return x

class EdgeDecoder(torch.nn.Module):
    def __init__(self, hidden_channels):
        super().__init__()
        self.lin1 = torch.nn.Linear(2 * hidden_channels, hidden_channels)
        self.lin2 = torch.nn.Linear(hidden_channels, 1)

    def forward(self, z_dict, edge_label_index):
        row, col = edge_label_index
        z = torch.cat([z_dict['user'][row], z_dict['movie'][col]], dim=-1)

        z = self.lin1(z).relu()
        z = self.lin2(z)
        return z.view(-1)

class Model(torch.nn.Module):
    def __init__(self, hidden_channels, user_dim):
        super().__init__()
        self.graph_embedding = GraphEmbedding(len(user_ids_tensor), user_dim)
        self.encoder = GNNEncoder(hidden_channels, hidden_channels)
        self.encoder = to_hetero(self.encoder, train_data.metadata(), aggr='sum')
        self.decoder = EdgeDecoder(hidden_channels)

    def forward(self, x_dict, edge_index_dict, edge_label_index):
        x_dict = self.graph_embedding(x_dict)
        z_dict = self.encoder(x_dict, edge_index_dict)
        return self.decoder(z_dict, edge_label_index)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = Model(hidden_channels=32, user_dim=100).to(device)
print(model)
# Out:
# Model(
#   (graph_embedding): GraphEmbedding(
#     (user_embedding): Embedding(610, 100)
#   )
#   (encoder): GraphModule(
#     (conv1): ModuleDict(
#       (user__rates__movie): SAGEConv((-1, -1), 32, aggr=mean)
#       (movie__rev_rates__user): SAGEConv((-1, -1), 32, aggr=mean)
#     )
#     (conv2): ModuleDict(
#       (user__rates__movie): SAGEConv((-1, -1), 32, aggr=mean)
#       (movie__rev_rates__user): SAGEConv((-1, -1), 32, aggr=mean)
#     )
#   )
#   (decoder): EdgeDecoder(
#     (lin1): Linear(in_features=64, out_features=32, bias=True)
#     (lin2): Linear(in_features=32, out_features=1, bias=True)
#   )
# )

# %%
# Initialize optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=0.005)

# Define training function
def train(model):
    model.train()
    optimizer.zero_grad()
    pred = model(train_data.x_dict, train_data.edge_index_dict,
                 train_data['user', 'movie'].edge_index)
    target = train_data['user', 'movie'].edge_label
    loss = F.mse_loss(pred, target)
    loss.backward()
    optimizer.step()
    return float(loss)

# Define test function
@torch.no_grad()
def test(model, data):
    data = data.to(device)
    model.eval()
    pred = model(data.x_dict, data.edge_index_dict,
                 data['user', 'movie'].edge_index)
    pred = pred.clamp(min=0, max=5)
    target = data['user', 'movie'].edge_label.float()
    rmse = F.mse_loss(pred, target).sqrt()
    return float(rmse)

best_val_rmse = float('inf')
best_epoch = 0

# Training loop
for epoch in range(1, 201):
    train_data = train_data.to(device) # type: ignore
    loss = train(model)
    train_rmse = test(model, train_data)
    val_rmse = test(model, val_data)

    # Check if the current validation RMSE is the best
    if val_rmse < best_val_rmse:
        best_val_rmse = val_rmse
        best_epoch = epoch
        torch.save(model.state_dict(), model_file_name)
        print(f'Saving model with val_rmse: {val_rmse:.4f} at epoch {epoch}')

    print(f'Epoch: {epoch:03d}, Loss: {loss:.4f}, Train: {train_rmse:.4f}, Val: {val_rmse:.4f}')
# Out:
# Saving model with val_rmse: 3.2175 at epoch 1
# Epoch: 001, Loss: 11.9625, Train: 3.2511, Val: 3.2175
# Saving model with val_rmse: 2.9568 at epoch 2
# Epoch: 002, Loss: 10.5696, Train: 3.0031, Val: 2.9568
# Saving model with val_rmse: 2.5973 at epoch 3
# Epoch: 003, Loss: 9.0185, Train: 2.6512, Val: 2.5973
# Saving model with val_rmse: 2.0966 at epoch 4
# Epoch: 004, Loss: 7.0288, Train: 2.1440, Val: 2.0966
# Saving model with val_rmse: 1.5031 at epoch 5
# Epoch: 005, Loss: 4.5967, Train: 1.4998, Val: 1.5031
# Saving model with val_rmse: 1.3251 at epoch 6
# Epoch: 006, Loss: 2.2493, Train: 1.2084, Val: 1.3251
# Epoch: 007, Loss: 1.5012, Train: 1.6417, Val: 1.6373
# Epoch: 008, Loss: 3.5295, Train: 1.6639, Val: 1.6568
# Epoch: 009, Loss: 3.5577, Train: 1.4462, Val: 1.5085
# Saving model with val_rmse: 1.2524 at epoch 10
# Epoch: 010, Loss: 2.2284, Train: 1.1465, Val: 1.2524
# Saving model with val_rmse: 1.1460 at epoch 11
# Epoch: 011, Loss: 1.3199, Train: 1.1001, Val: 1.1460
# Epoch: 012, Loss: 1.2103, Train: 1.2355, Val: 1.2334
# Epoch: 013, Loss: 1.5265, Train: 1.3660, Val: 1.3427
# Epoch: 014, Loss: 1.8658, Train: 1.4246, Val: 1.3942
# Epoch: 015, Loss: 2.0294, Train: 1.4057, Val: 1.3761
# Epoch: 016, Loss: 1.9761, Train: 1.3224, Val: 1.3002
# Epoch: 017, Loss: 1.7487, Train: 1.1984, Val: 1.1928
# Saving model with val_rmse: 1.0990 at epoch 18
# Epoch: 018, Loss: 1.4361, Train: 1.0753, Val: 1.0990
# Saving model with val_rmse: 1.0752 at epoch 19
# Epoch: 019, Loss: 1.1564, Train: 1.0133, Val: 1.0752
# Epoch: 020, Loss: 1.0273, Train: 1.0491, Val: 1.1394
# Epoch: 021, Loss: 1.1035, Train: 1.1373, Val: 1.2338
# Epoch: 022, Loss: 1.3018, Train: 1.1907, Val: 1.2842
# Epoch: 023, Loss: 1.4316, Train: 1.1678, Val: 1.2626
# Epoch: 024, Loss: 1.3748, Train: 1.0907, Val: 1.1867
# Epoch: 025, Loss: 1.1947, Train: 1.0157, Val: 1.1014
# Saving model with val_rmse: 1.0507 at epoch 26
# Epoch: 026, Loss: 1.0333, Train: 0.9873, Val: 1.0507
# Saving model with val_rmse: 1.0448 at epoch 27
# Epoch: 027, Loss: 0.9751, Train: 1.0056, Val: 1.0448
# Epoch: 028, Loss: 1.0113, Train: 1.0411, Val: 1.0625
# Epoch: 029, Loss: 1.0839, Train: 1.0660, Val: 1.0781
# Epoch: 030, Loss: 1.1363, Train: 1.0670, Val: 1.0773
# Epoch: 031, Loss: 1.1385, Train: 1.0443, Val: 1.0593
# Saving model with val_rmse: 1.0338 at epoch 32
# Epoch: 032, Loss: 1.0905, Train: 1.0081, Val: 1.0338
# Saving model with val_rmse: 1.0165 at epoch 33
# Epoch: 033, Loss: 1.0162, Train: 0.9752, Val: 1.0165
# Epoch: 034, Loss: 0.9510, Train: 0.9616, Val: 1.0202
# Epoch: 035, Loss: 0.9248, Train: 0.9713, Val: 1.0441
# Epoch: 036, Loss: 0.9437, Train: 0.9912, Val: 1.0721
# Epoch: 037, Loss: 0.9831, Train: 1.0018, Val: 1.0853
# Epoch: 038, Loss: 1.0043, Train: 0.9934, Val: 1.0755
# Epoch: 039, Loss: 0.9874, Train: 0.9722, Val: 1.0488
# Epoch: 040, Loss: 0.9455, Train: 0.9530, Val: 1.0196
# Saving model with val_rmse: 1.0006 at epoch 41
# Epoch: 041, Loss: 0.9083, Train: 0.9462, Val: 1.0006
# Saving model with val_rmse: 0.9944 at epoch 42
# Epoch: 042, Loss: 0.8954, Train: 0.9512, Val: 0.9944
# Epoch: 043, Loss: 0.9049, Train: 0.9599, Val: 0.9953
# Epoch: 044, Loss: 0.9214, Train: 0.9639, Val: 0.9962
# Saving model with val_rmse: 0.9937 at epoch 45
# Epoch: 045, Loss: 0.9291, Train: 0.9599, Val: 0.9937
# Saving model with val_rmse: 0.9894 at epoch 46
# Epoch: 046, Loss: 0.9214, Train: 0.9498, Val: 0.9894
# Saving model with val_rmse: 0.9877 at epoch 47
# Epoch: 047, Loss: 0.9021, Train: 0.9394, Val: 0.9877
# Epoch: 048, Loss: 0.8825, Train: 0.9341, Val: 0.9922
# Epoch: 049, Loss: 0.8726, Train: 0.9355, Val: 1.0022
# Epoch: 050, Loss: 0.8752, Train: 0.9398, Val: 1.0125
# Epoch: 051, Loss: 0.8835, Train: 0.9417, Val: 1.0170
# Epoch: 052, Loss: 0.8872, Train: 0.9384, Val: 1.0132
# Epoch: 053, Loss: 0.8809, Train: 0.9319, Val: 1.0034
# Epoch: 054, Loss: 0.8686, Train: 0.9264, Val: 0.9926
# Saving model with val_rmse: 0.9849 at epoch 55
# Epoch: 055, Loss: 0.8584, Train: 0.9247, Val: 0.9849
# Saving model with val_rmse: 0.9811 at epoch 56
# Epoch: 056, Loss: 0.8551, Train: 0.9259, Val: 0.9811
# Saving model with val_rmse: 0.9797 at epoch 57
# Epoch: 057, Loss: 0.8574, Train: 0.9274, Val: 0.9797
# Saving model with val_rmse: 0.9791 at epoch 58
# Epoch: 058, Loss: 0.8601, Train: 0.9268, Val: 0.9791
# Saving model with val_rmse: 0.9789 at epoch 59
# Epoch: 059, Loss: 0.8591, Train: 0.9239, Val: 0.9789
# Epoch: 060, Loss: 0.8537, Train: 0.9201, Val: 0.9798
# Epoch: 061, Loss: 0.8467, Train: 0.9175, Val: 0.9828
# Epoch: 062, Loss: 0.8419, Train: 0.9169, Val: 0.9876
# Epoch: 063, Loss: 0.8408, Train: 0.9174, Val: 0.9920
# Epoch: 064, Loss: 0.8420, Train: 0.9175, Val: 0.9940
# Epoch: 065, Loss: 0.8421, Train: 0.9160, Val: 0.9925
# Epoch: 066, Loss: 0.8394, Train: 0.9136, Val: 0.9883
# Epoch: 067, Loss: 0.8350, Train: 0.9116, Val: 0.9833
# Epoch: 068, Loss: 0.8312, Train: 0.9106, Val: 0.9792
# Saving model with val_rmse: 0.9766 at epoch 69
# Epoch: 069, Loss: 0.8294, Train: 0.9106, Val: 0.9766
# Saving model with val_rmse: 0.9753 at epoch 70
# Epoch: 070, Loss: 0.8292, Train: 0.9104, Val: 0.9753
# Saving model with val_rmse: 0.9750 at epoch 71
# Epoch: 071, Loss: 0.8289, Train: 0.9095, Val: 0.9750
# Epoch: 072, Loss: 0.8273, Train: 0.9080, Val: 0.9754
# Epoch: 073, Loss: 0.8246, Train: 0.9065, Val: 0.9769
# Epoch: 074, Loss: 0.8218, Train: 0.9055, Val: 0.9791
# Epoch: 075, Loss: 0.8201, Train: 0.9050, Val: 0.9814
# Epoch: 076, Loss: 0.8193, Train: 0.9047, Val: 0.9827
# Epoch: 077, Loss: 0.8187, Train: 0.9040, Val: 0.9825
# Epoch: 078, Loss: 0.8175, Train: 0.9029, Val: 0.9807
# Epoch: 079, Loss: 0.8155, Train: 0.9017, Val: 0.9782
# Epoch: 080, Loss: 0.8134, Train: 0.9009, Val: 0.9756
# Saving model with val_rmse: 0.9737 at epoch 81
# Epoch: 081, Loss: 0.8119, Train: 0.9005, Val: 0.9737
# Saving model with val_rmse: 0.9725 at epoch 82
# Epoch: 082, Loss: 0.8110, Train: 0.9000, Val: 0.9725
# Saving model with val_rmse: 0.9721 at epoch 83
# Epoch: 083, Loss: 0.8102, Train: 0.8993, Val: 0.9721
# Epoch: 084, Loss: 0.8090, Train: 0.8984, Val: 0.9724
# Epoch: 085, Loss: 0.8074, Train: 0.8975, Val: 0.9733
# Epoch: 086, Loss: 0.8058, Train: 0.8968, Val: 0.9744
# Epoch: 087, Loss: 0.8045, Train: 0.8963, Val: 0.9754
# Epoch: 088, Loss: 0.8036, Train: 0.8957, Val: 0.9759
# Epoch: 089, Loss: 0.8026, Train: 0.8951, Val: 0.9754
# Epoch: 090, Loss: 0.8015, Train: 0.8943, Val: 0.9742
# Epoch: 091, Loss: 0.8001, Train: 0.8936, Val: 0.9726
# Saving model with val_rmse: 0.9711 at epoch 92
# Epoch: 092, Loss: 0.7987, Train: 0.8930, Val: 0.9711
# Saving model with val_rmse: 0.9699 at epoch 93
# Epoch: 093, Loss: 0.7976, Train: 0.8924, Val: 0.9699
# Saving model with val_rmse: 0.9692 at epoch 94
# Epoch: 094, Loss: 0.7966, Train: 0.8919, Val: 0.9692
# Saving model with val_rmse: 0.9689 at epoch 95
# Epoch: 095, Loss: 0.7956, Train: 0.8912, Val: 0.9689
# Epoch: 096, Loss: 0.7945, Train: 0.8905, Val: 0.9690
# Epoch: 097, Loss: 0.7932, Train: 0.8899, Val: 0.9694
# Epoch: 098, Loss: 0.7921, Train: 0.8893, Val: 0.9698
# Epoch: 099, Loss: 0.7910, Train: 0.8888, Val: 0.9700
# Epoch: 100, Loss: 0.7901, Train: 0.8882, Val: 0.9697
# Epoch: 101, Loss: 0.7891, Train: 0.8876, Val: 0.9691
# Saving model with val_rmse: 0.9683 at epoch 102
# Epoch: 102, Loss: 0.7880, Train: 0.8870, Val: 0.9683
# Saving model with val_rmse: 0.9675 at epoch 103
# Epoch: 103, Loss: 0.7869, Train: 0.8864, Val: 0.9675
# Saving model with val_rmse: 0.9668 at epoch 104
# Epoch: 104, Loss: 0.7858, Train: 0.8858, Val: 0.9668
# Saving model with val_rmse: 0.9665 at epoch 105
# Epoch: 105, Loss: 0.7848, Train: 0.8852, Val: 0.9665
# Saving model with val_rmse: 0.9664 at epoch 106
# Epoch: 106, Loss: 0.7838, Train: 0.8846, Val: 0.9664
# Epoch: 107, Loss: 0.7828, Train: 0.8841, Val: 0.9666
# Epoch: 108, Loss: 0.7817, Train: 0.8835, Val: 0.9669
# Epoch: 109, Loss: 0.7807, Train: 0.8829, Val: 0.9672
# Epoch: 110, Loss: 0.7797, Train: 0.8824, Val: 0.9673
# Epoch: 111, Loss: 0.7787, Train: 0.8818, Val: 0.9672
# Epoch: 112, Loss: 0.7778, Train: 0.8813, Val: 0.9669
# Epoch: 113, Loss: 0.7768, Train: 0.8807, Val: 0.9666
# Saving model with val_rmse: 0.9663 at epoch 114
# Epoch: 114, Loss: 0.7758, Train: 0.8802, Val: 0.9663
# Saving model with val_rmse: 0.9662 at epoch 115
# Epoch: 115, Loss: 0.7748, Train: 0.8796, Val: 0.9662
# Saving model with val_rmse: 0.9662 at epoch 116
# Epoch: 116, Loss: 0.7739, Train: 0.8791, Val: 0.9662
# Epoch: 117, Loss: 0.7730, Train: 0.8786, Val: 0.9663
# Epoch: 118, Loss: 0.7720, Train: 0.8780, Val: 0.9665
# Epoch: 119, Loss: 0.7711, Train: 0.8775, Val: 0.9666
# Epoch: 120, Loss: 0.7702, Train: 0.8770, Val: 0.9667
# Epoch: 121, Loss: 0.7693, Train: 0.8765, Val: 0.9666
# Epoch: 122, Loss: 0.7683, Train: 0.8760, Val: 0.9665
# Epoch: 123, Loss: 0.7675, Train: 0.8755, Val: 0.9664
# Epoch: 124, Loss: 0.7666, Train: 0.8750, Val: 0.9663
# Epoch: 125, Loss: 0.7657, Train: 0.8745, Val: 0.9662
# Epoch: 126, Loss: 0.7648, Train: 0.8740, Val: 0.9663
# Epoch: 127, Loss: 0.7640, Train: 0.8735, Val: 0.9663
# Epoch: 128, Loss: 0.7631, Train: 0.8730, Val: 0.9663
# Epoch: 129, Loss: 0.7623, Train: 0.8725, Val: 0.9663
# Epoch: 130, Loss: 0.7614, Train: 0.8720, Val: 0.9663
# Epoch: 131, Loss: 0.7606, Train: 0.8715, Val: 0.9662
# Epoch: 132, Loss: 0.7597, Train: 0.8711, Val: 0.9662
# Epoch: 133, Loss: 0.7589, Train: 0.8706, Val: 0.9662
# Epoch: 134, Loss: 0.7580, Train: 0.8701, Val: 0.9662
# Epoch: 135, Loss: 0.7572, Train: 0.8696, Val: 0.9662
# Epoch: 136, Loss: 0.7564, Train: 0.8692, Val: 0.9663
# Epoch: 137, Loss: 0.7556, Train: 0.8687, Val: 0.9664
# Epoch: 138, Loss: 0.7548, Train: 0.8683, Val: 0.9665
# Epoch: 139, Loss: 0.7540, Train: 0.8678, Val: 0.9666
# Epoch: 140, Loss: 0.7533, Train: 0.8674, Val: 0.9667
# Epoch: 141, Loss: 0.7525, Train: 0.8670, Val: 0.9668
# Epoch: 142, Loss: 0.7517, Train: 0.8665, Val: 0.9669
# Epoch: 143, Loss: 0.7510, Train: 0.8661, Val: 0.9670
# Epoch: 144, Loss: 0.7503, Train: 0.8657, Val: 0.9671
# Epoch: 145, Loss: 0.7495, Train: 0.8653, Val: 0.9672
# Epoch: 146, Loss: 0.7488, Train: 0.8649, Val: 0.9673
# Epoch: 147, Loss: 0.7481, Train: 0.8645, Val: 0.9674
# Epoch: 148, Loss: 0.7474, Train: 0.8641, Val: 0.9675
# Epoch: 149, Loss: 0.7467, Train: 0.8637, Val: 0.9675
# Epoch: 150, Loss: 0.7460, Train: 0.8633, Val: 0.9676
# Epoch: 151, Loss: 0.7453, Train: 0.8629, Val: 0.9676
# Epoch: 152, Loss: 0.7446, Train: 0.8625, Val: 0.9676
# Epoch: 153, Loss: 0.7440, Train: 0.8621, Val: 0.9676
# Epoch: 154, Loss: 0.7433, Train: 0.8617, Val: 0.9677
# Epoch: 155, Loss: 0.7427, Train: 0.8613, Val: 0.9677
# Epoch: 156, Loss: 0.7420, Train: 0.8610, Val: 0.9678
# Epoch: 157, Loss: 0.7414, Train: 0.8606, Val: 0.9678
# Epoch: 158, Loss: 0.7407, Train: 0.8602, Val: 0.9679
# Epoch: 159, Loss: 0.7401, Train: 0.8599, Val: 0.9680
# Epoch: 160, Loss: 0.7395, Train: 0.8595, Val: 0.9681
# Epoch: 161, Loss: 0.7389, Train: 0.8591, Val: 0.9683
# Epoch: 162, Loss: 0.7382, Train: 0.8588, Val: 0.9685
# Epoch: 163, Loss: 0.7376, Train: 0.8584, Val: 0.9687
# Epoch: 164, Loss: 0.7370, Train: 0.8581, Val: 0.9690
# Epoch: 165, Loss: 0.7364, Train: 0.8577, Val: 0.9692
# Epoch: 166, Loss: 0.7358, Train: 0.8574, Val: 0.9694
# Epoch: 167, Loss: 0.7353, Train: 0.8571, Val: 0.9695
# Epoch: 168, Loss: 0.7347, Train: 0.8567, Val: 0.9697
# Epoch: 169, Loss: 0.7341, Train: 0.8564, Val: 0.9699
# Epoch: 170, Loss: 0.7335, Train: 0.8561, Val: 0.9700
# Epoch: 171, Loss: 0.7330, Train: 0.8557, Val: 0.9702
# Epoch: 172, Loss: 0.7324, Train: 0.8554, Val: 0.9704
# Epoch: 173, Loss: 0.7318, Train: 0.8551, Val: 0.9706
# Epoch: 174, Loss: 0.7313, Train: 0.8548, Val: 0.9708
# Epoch: 175, Loss: 0.7308, Train: 0.8545, Val: 0.9710
# Epoch: 176, Loss: 0.7302, Train: 0.8542, Val: 0.9712
# Epoch: 177, Loss: 0.7297, Train: 0.8538, Val: 0.9714
# Epoch: 178, Loss: 0.7292, Train: 0.8535, Val: 0.9716
# Epoch: 179, Loss: 0.7287, Train: 0.8532, Val: 0.9718
# Epoch: 180, Loss: 0.7282, Train: 0.8529, Val: 0.9721
# Epoch: 181, Loss: 0.7277, Train: 0.8527, Val: 0.9724
# Epoch: 182, Loss: 0.7272, Train: 0.8524, Val: 0.9726
# Epoch: 183, Loss: 0.7267, Train: 0.8521, Val: 0.9728
# Epoch: 184, Loss: 0.7262, Train: 0.8518, Val: 0.9730
# Epoch: 185, Loss: 0.7257, Train: 0.8515, Val: 0.9732
# Epoch: 186, Loss: 0.7252, Train: 0.8512, Val: 0.9734
# Epoch: 187, Loss: 0.7247, Train: 0.8509, Val: 0.9736
# Epoch: 188, Loss: 0.7242, Train: 0.8507, Val: 0.9737
# Epoch: 189, Loss: 0.7238, Train: 0.8504, Val: 0.9739
# Epoch: 190, Loss: 0.7233, Train: 0.8501, Val: 0.9742
# Epoch: 191, Loss: 0.7228, Train: 0.8498, Val: 0.9745
# Epoch: 192, Loss: 0.7224, Train: 0.8496, Val: 0.9747
# Epoch: 193, Loss: 0.7219, Train: 0.8493, Val: 0.9749
# Epoch: 194, Loss: 0.7214, Train: 0.8490, Val: 0.9752
# Epoch: 195, Loss: 0.7210, Train: 0.8488, Val: 0.9753
# Epoch: 196, Loss: 0.7205, Train: 0.8485, Val: 0.9755
# Epoch: 197, Loss: 0.7201, Train: 0.8482, Val: 0.9757
# Epoch: 198, Loss: 0.7196, Train: 0.8480, Val: 0.9759
# Epoch: 199, Loss: 0.7192, Train: 0.8477, Val: 0.9761
# Epoch: 200, Loss: 0.7188, Train: 0.8475, Val: 0.9763
# Epoch: 201, Loss: 0.7183, Train: 0.8472, Val: 0.9765
# Epoch: 202, Loss: 0.7179, Train: 0.8469, Val: 0.9768
# Epoch: 203, Loss: 0.7175, Train: 0.8467, Val: 0.9770
# Epoch: 204, Loss: 0.7170, Train: 0.8464, Val: 0.9773
# Epoch: 205, Loss: 0.7166, Train: 0.8462, Val: 0.9776
# Epoch: 206, Loss: 0.7162, Train: 0.8459, Val: 0.9780
# Epoch: 207, Loss: 0.7158, Train: 0.8457, Val: 0.9782
# Epoch: 208, Loss: 0.7154, Train: 0.8454, Val: 0.9786
# Epoch: 209, Loss: 0.7149, Train: 0.8452, Val: 0.9790
# Epoch: 210, Loss: 0.7145, Train: 0.8450, Val: 0.9793
# Epoch: 211, Loss: 0.7141, Train: 0.8447, Val: 0.9796
# Epoch: 212, Loss: 0.7137, Train: 0.8445, Val: 0.9800
# Epoch: 213, Loss: 0.7133, Train: 0.8443, Val: 0.9803
# Epoch: 214, Loss: 0.7129, Train: 0.8440, Val: 0.9807
# Epoch: 215, Loss: 0.7125, Train: 0.8438, Val: 0.9811
# Epoch: 216, Loss: 0.7121, Train: 0.8436, Val: 0.9814
# Epoch: 217, Loss: 0.7118, Train: 0.8433, Val: 0.9817
# Epoch: 218, Loss: 0.7114, Train: 0.8431, Val: 0.9820
# Epoch: 219, Loss: 0.7110, Train: 0.8429, Val: 0.9823
# Epoch: 220, Loss: 0.7106, Train: 0.8426, Val: 0.9825
# Epoch: 221, Loss: 0.7102, Train: 0.8424, Val: 0.9829
# Epoch: 222, Loss: 0.7098, Train: 0.8422, Val: 0.9831
# Epoch: 223, Loss: 0.7095, Train: 0.8420, Val: 0.9834
# Epoch: 224, Loss: 0.7091, Train: 0.8417, Val: 0.9838
# Epoch: 225, Loss: 0.7087, Train: 0.8415, Val: 0.9841
# Epoch: 226, Loss: 0.7084, Train: 0.8413, Val: 0.9843
# Epoch: 227, Loss: 0.7080, Train: 0.8411, Val: 0.9847
# Epoch: 228, Loss: 0.7076, Train: 0.8409, Val: 0.9853
# Epoch: 229, Loss: 0.7073, Train: 0.8407, Val: 0.9855
# Epoch: 230, Loss: 0.7069, Train: 0.8405, Val: 0.9858
# Epoch: 231, Loss: 0.7066, Train: 0.8403, Val: 0.9863
# Epoch: 232, Loss: 0.7062, Train: 0.8400, Val: 0.9864
# Epoch: 233, Loss: 0.7059, Train: 0.8398, Val: 0.9866
# Epoch: 234, Loss: 0.7055, Train: 0.8396, Val: 0.9871
# Epoch: 235, Loss: 0.7052, Train: 0.8394, Val: 0.9876
# Epoch: 236, Loss: 0.7048, Train: 0.8392, Val: 0.9878
# Epoch: 237, Loss: 0.7045, Train: 0.8390, Val: 0.9881
# Epoch: 238, Loss: 0.7041, Train: 0.8388, Val: 0.9885
# Epoch: 239, Loss: 0.7038, Train: 0.8386, Val: 0.9890
# Epoch: 240, Loss: 0.7034, Train: 0.8384, Val: 0.9891
# Epoch: 241, Loss: 0.7031, Train: 0.8382, Val: 0.9895
# Epoch: 242, Loss: 0.7027, Train: 0.8380, Val: 0.9898
# Epoch: 243, Loss: 0.7024, Train: 0.8378, Val: 0.9900
# Epoch: 244, Loss: 0.7021, Train: 0.8376, Val: 0.9903
# Epoch: 245, Loss: 0.7017, Train: 0.8374, Val: 0.9906
# Epoch: 246, Loss: 0.7014, Train: 0.8372, Val: 0.9907
# Epoch: 247, Loss: 0.7010, Train: 0.8369, Val: 0.9910
# Epoch: 248, Loss: 0.7007, Train: 0.8367, Val: 0.9913
# Epoch: 249, Loss: 0.7003, Train: 0.8365, Val: 0.9916
# Epoch: 250, Loss: 0.7000, Train: 0.8363, Val: 0.9920
# Epoch: 251, Loss: 0.6996, Train: 0.8361, Val: 0.9924
# Epoch: 252, Loss: 0.6993, Train: 0.8359, Val: 0.9927
# Epoch: 253, Loss: 0.6990, Train: 0.8357, Val: 0.9932
# Epoch: 254, Loss: 0.6986, Train: 0.8355, Val: 0.9934
# Epoch: 255, Loss: 0.6983, Train: 0.8353, Val: 0.9937
# Epoch: 256, Loss: 0.6979, Train: 0.8351, Val: 0.9940
# Epoch: 257, Loss: 0.6976, Train: 0.8349, Val: 0.9941
# Epoch: 258, Loss: 0.6973, Train: 0.8347, Val: 0.9945
# Epoch: 259, Loss: 0.6969, Train: 0.8345, Val: 0.9948
# Epoch: 260, Loss: 0.6966, Train: 0.8343, Val: 0.9952
# Epoch: 261, Loss: 0.6963, Train: 0.8341, Val: 0.9954
# Epoch: 262, Loss: 0.6959, Train: 0.8339, Val: 0.9958
# Epoch: 263, Loss: 0.6956, Train: 0.8337, Val: 0.9961
# Epoch: 264, Loss: 0.6953, Train: 0.8335, Val: 0.9965
# Epoch: 265, Loss: 0.6950, Train: 0.8333, Val: 0.9968
# Epoch: 266, Loss: 0.6947, Train: 0.8331, Val: 0.9972
# Epoch: 267, Loss: 0.6944, Train: 0.8330, Val: 0.9973
# Epoch: 268, Loss: 0.6940, Train: 0.8328, Val: 0.9979
# Epoch: 269, Loss: 0.6937, Train: 0.8326, Val: 0.9985
# Epoch: 270, Loss: 0.6934, Train: 0.8324, Val: 0.9984
# Epoch: 271, Loss: 0.6931, Train: 0.8322, Val: 0.9988
# Epoch: 272, Loss: 0.6928, Train: 0.8321, Val: 0.9995
# Epoch: 273, Loss: 0.6925, Train: 0.8319, Val: 0.9997
# Epoch: 274, Loss: 0.6922, Train: 0.8317, Val: 0.9999
# Epoch: 275, Loss: 0.6919, Train: 0.8315, Val: 1.0006
# Epoch: 276, Loss: 0.6916, Train: 0.8313, Val: 1.0013
# Epoch: 277, Loss: 0.6914, Train: 0.8312, Val: 1.0015
# Epoch: 278, Loss: 0.6911, Train: 0.8310, Val: 1.0019
# Epoch: 279, Loss: 0.6908, Train: 0.8308, Val: 1.0025
# Epoch: 280, Loss: 0.6905, Train: 0.8307, Val: 1.0028
# Epoch: 281, Loss: 0.6902, Train: 0.8305, Val: 1.0031
# Epoch: 282, Loss: 0.6900, Train: 0.8303, Val: 1.0036
# Epoch: 283, Loss: 0.6897, Train: 0.8302, Val: 1.0040
# Epoch: 284, Loss: 0.6894, Train: 0.8300, Val: 1.0044
# Epoch: 285, Loss: 0.6891, Train: 0.8298, Val: 1.0049
# Epoch: 286, Loss: 0.6888, Train: 0.8297, Val: 1.0052
# Epoch: 287, Loss: 0.6886, Train: 0.8295, Val: 1.0057
# Epoch: 288, Loss: 0.6883, Train: 0.8293, Val: 1.0061
# Epoch: 289, Loss: 0.6880, Train: 0.8292, Val: 1.0062
# Epoch: 290, Loss: 0.6878, Train: 0.8290, Val: 1.0067
# Epoch: 291, Loss: 0.6875, Train: 0.8289, Val: 1.0071
# Epoch: 292, Loss: 0.6872, Train: 0.8287, Val: 1.0075
# Epoch: 293, Loss: 0.6870, Train: 0.8285, Val: 1.0081
# Epoch: 294, Loss: 0.6867, Train: 0.8284, Val: 1.0084
# Epoch: 295, Loss: 0.6864, Train: 0.8282, Val: 1.0089
# Epoch: 296, Loss: 0.6862, Train: 0.8281, Val: 1.0093
# Epoch: 297, Loss: 0.6859, Train: 0.8279, Val: 1.0094
# Epoch: 298, Loss: 0.6857, Train: 0.8277, Val: 1.0098
# Epoch: 299, Loss: 0.6854, Train: 0.8276, Val: 1.0101
# Epoch: 300, Loss: 0.6851, Train: 0.8274, Val: 1.0103
# Epoch: 301, Loss: 0.6849, Train: 0.8273, Val: 1.0108
# Epoch: 302, Loss: 0.6846, Train: 0.8271, Val: 1.0114
# Epoch: 303, Loss: 0.6844, Train: 0.8270, Val: 1.0115
# Epoch: 304, Loss: 0.6841, Train: 0.8268, Val: 1.0119
# Epoch: 305, Loss: 0.6839, Train: 0.8266, Val: 1.0122
# Epoch: 306, Loss: 0.6836, Train: 0.8265, Val: 1.0124
# Epoch: 307, Loss: 0.6833, Train: 0.8263, Val: 1.0128
# Epoch: 308, Loss: 0.6831, Train: 0.8262, Val: 1.0134
# Epoch: 309, Loss: 0.6828, Train: 0.8260, Val: 1.0136
# Epoch: 310, Loss: 0.6826, Train: 0.8259, Val: 1.0140
# Epoch: 311, Loss: 0.6823, Train: 0.8257, Val: 1.0144
# Epoch: 312, Loss: 0.6821, Train: 0.8256, Val: 1.0146
# Epoch: 313, Loss: 0.6818, Train: 0.8254, Val: 1.0153
# Epoch: 314, Loss: 0.6816, Train: 0.8253, Val: 1.0157
# Epoch: 315, Loss: 0.6813, Train: 0.8251, Val: 1.0161
# Epoch: 316, Loss: 0.6811, Train: 0.8250, Val: 1.0166
# Epoch: 317, Loss: 0.6808, Train: 0.8248, Val: 1.0171
# Epoch: 318, Loss: 0.6806, Train: 0.8247, Val: 1.0175
# Epoch: 319, Loss: 0.6803, Train: 0.8245, Val: 1.0184
# Epoch: 320, Loss: 0.6801, Train: 0.8244, Val: 1.0186
# Epoch: 321, Loss: 0.6799, Train: 0.8242, Val: 1.0192
# Epoch: 322, Loss: 0.6796, Train: 0.8241, Val: 1.0197
# Epoch: 323, Loss: 0.6794, Train: 0.8240, Val: 1.0199
# Epoch: 324, Loss: 0.6792, Train: 0.8238, Val: 1.0205
# Epoch: 325, Loss: 0.6789, Train: 0.8237, Val: 1.0210
# Epoch: 326, Loss: 0.6787, Train: 0.8235, Val: 1.0214
# Epoch: 327, Loss: 0.6784, Train: 0.8234, Val: 1.0215
# Epoch: 328, Loss: 0.6782, Train: 0.8232, Val: 1.0225
# Epoch: 329, Loss: 0.6780, Train: 0.8231, Val: 1.0226
# Epoch: 330, Loss: 0.6777, Train: 0.8229, Val: 1.0229
# Epoch: 331, Loss: 0.6775, Train: 0.8228, Val: 1.0237
# Epoch: 332, Loss: 0.6773, Train: 0.8227, Val: 1.0236
# Epoch: 333, Loss: 0.6771, Train: 0.8225, Val: 1.0242
# Epoch: 334, Loss: 0.6768, Train: 0.8224, Val: 1.0248
# Epoch: 335, Loss: 0.6766, Train: 0.8223, Val: 1.0250
# Epoch: 336, Loss: 0.6764, Train: 0.8221, Val: 1.0257
# Epoch: 337, Loss: 0.6761, Train: 0.8220, Val: 1.0262
# Epoch: 338, Loss: 0.6759, Train: 0.8218, Val: 1.0262
# Epoch: 339, Loss: 0.6757, Train: 0.8217, Val: 1.0267
# Epoch: 340, Loss: 0.6755, Train: 0.8216, Val: 1.0273
# Epoch: 341, Loss: 0.6752, Train: 0.8214, Val: 1.0275
# Epoch: 342, Loss: 0.6750, Train: 0.8213, Val: 1.0283
# Epoch: 343, Loss: 0.6748, Train: 0.8212, Val: 1.0287
# Epoch: 344, Loss: 0.6746, Train: 0.8210, Val: 1.0289
# Epoch: 345, Loss: 0.6744, Train: 0.8209, Val: 1.0297
# Epoch: 346, Loss: 0.6741, Train: 0.8207, Val: 1.0300
# Epoch: 347, Loss: 0.6739, Train: 0.8206, Val: 1.0307
# Epoch: 348, Loss: 0.6737, Train: 0.8205, Val: 1.0309
# Epoch: 349, Loss: 0.6735, Train: 0.8204, Val: 1.0319
# Epoch: 350, Loss: 0.6733, Train: 0.8202, Val: 1.0319
# Epoch: 351, Loss: 0.6731, Train: 0.8201, Val: 1.0326
# Epoch: 352, Loss: 0.6728, Train: 0.8200, Val: 1.0333
# Epoch: 353, Loss: 0.6726, Train: 0.8198, Val: 1.0335
# Epoch: 354, Loss: 0.6724, Train: 0.8197, Val: 1.0341
# Epoch: 355, Loss: 0.6722, Train: 0.8196, Val: 1.0346
# Epoch: 356, Loss: 0.6720, Train: 0.8194, Val: 1.0350
# Epoch: 357, Loss: 0.6717, Train: 0.8193, Val: 1.0355
# Epoch: 358, Loss: 0.6715, Train: 0.8192, Val: 1.0363
# Epoch: 359, Loss: 0.6713, Train: 0.8190, Val: 1.0363
# Epoch: 360, Loss: 0.6711, Train: 0.8189, Val: 1.0368
# Epoch: 361, Loss: 0.6709, Train: 0.8188, Val: 1.0374
# Epoch: 362, Loss: 0.6707, Train: 0.8186, Val: 1.0380
# Epoch: 363, Loss: 0.6704, Train: 0.8185, Val: 1.0382
# Epoch: 364, Loss: 0.6702, Train: 0.8184, Val: 1.0390
# Epoch: 365, Loss: 0.6700, Train: 0.8182, Val: 1.0394
# Epoch: 366, Loss: 0.6698, Train: 0.8181, Val: 1.0401
# Epoch: 367, Loss: 0.6696, Train: 0.8180, Val: 1.0406
# Epoch: 368, Loss: 0.6694, Train: 0.8179, Val: 1.0406
# Epoch: 369, Loss: 0.6692, Train: 0.8177, Val: 1.0412
# Epoch: 370, Loss: 0.6690, Train: 0.8176, Val: 1.0415
# Epoch: 371, Loss: 0.6688, Train: 0.8175, Val: 1.0424
# Epoch: 372, Loss: 0.6686, Train: 0.8173, Val: 1.0423
# Epoch: 373, Loss: 0.6684, Train: 0.8172, Val: 1.0431
# Epoch: 374, Loss: 0.6681, Train: 0.8171, Val: 1.0436
# Epoch: 375, Loss: 0.6679, Train: 0.8169, Val: 1.0440
# Epoch: 376, Loss: 0.6677, Train: 0.8168, Val: 1.0444
# Epoch: 377, Loss: 0.6675, Train: 0.8167, Val: 1.0449
# Epoch: 378, Loss: 0.6673, Train: 0.8166, Val: 1.0457
# Epoch: 379, Loss: 0.6671, Train: 0.8164, Val: 1.0464
# Epoch: 380, Loss: 0.6669, Train: 0.8163, Val: 1.0469
# Epoch: 381, Loss: 0.6667, Train: 0.8162, Val: 1.0470
# Epoch: 382, Loss: 0.6665, Train: 0.8161, Val: 1.0483
# Epoch: 383, Loss: 0.6663, Train: 0.8160, Val: 1.0479
# Epoch: 384, Loss: 0.6661, Train: 0.8159, Val: 1.0490
# Epoch: 385, Loss: 0.6659, Train: 0.8157, Val: 1.0495
# Epoch: 386, Loss: 0.6657, Train: 0.8156, Val: 1.0498
# Epoch: 387, Loss: 0.6655, Train: 0.8155, Val: 1.0506
# Epoch: 388, Loss: 0.6653, Train: 0.8153, Val: 1.0510
# Epoch: 389, Loss: 0.6651, Train: 0.8152, Val: 1.0516
# Epoch: 390, Loss: 0.6649, Train: 0.8151, Val: 1.0518
# Epoch: 391, Loss: 0.6647, Train: 0.8150, Val: 1.0525
# Epoch: 392, Loss: 0.6646, Train: 0.8149, Val: 1.0523
# Epoch: 393, Loss: 0.6644, Train: 0.8148, Val: 1.0536
# Epoch: 394, Loss: 0.6642, Train: 0.8147, Val: 1.0536
# Epoch: 395, Loss: 0.6640, Train: 0.8145, Val: 1.0546
# Epoch: 396, Loss: 0.6638, Train: 0.8144, Val: 1.0549
# Epoch: 397, Loss: 0.6636, Train: 0.8143, Val: 1.0558
# Epoch: 398, Loss: 0.6634, Train: 0.8142, Val: 1.0560
# Epoch: 399, Loss: 0.6632, Train: 0.8141, Val: 1.0566
# Epoch: 400, Loss: 0.6630, Train: 0.8140, Val: 1.0568
# Epoch: 401, Loss: 0.6629, Train: 0.8139, Val: 1.0575
# Epoch: 402, Loss: 0.6627, Train: 0.8138, Val: 1.0575
# Epoch: 403, Loss: 0.6626, Train: 0.8137, Val: 1.0588
# Epoch: 404, Loss: 0.6624, Train: 0.8136, Val: 1.0580
# Epoch: 405, Loss: 0.6624, Train: 0.8136, Val: 1.0599
# Epoch: 406, Loss: 0.6622, Train: 0.8134, Val: 1.0590
# Epoch: 407, Loss: 0.6620, Train: 0.8133, Val: 1.0604
# Epoch: 408, Loss: 0.6617, Train: 0.8132, Val: 1.0610
# Epoch: 409, Loss: 0.6616, Train: 0.8131, Val: 1.0607
# Epoch: 410, Loss: 0.6614, Train: 0.8131, Val: 1.0625
# Epoch: 411, Loss: 0.6614, Train: 0.8129, Val: 1.0624
# Epoch: 412, Loss: 0.6612, Train: 0.8128, Val: 1.0631
# Epoch: 413, Loss: 0.6609, Train: 0.8127, Val: 1.0630
# Epoch: 414, Loss: 0.6607, Train: 0.8126, Val: 1.0636
# Epoch: 415, Loss: 0.6606, Train: 0.8125, Val: 1.0651
# Epoch: 416, Loss: 0.6605, Train: 0.8124, Val: 1.0643
# Epoch: 417, Loss: 0.6603, Train: 0.8123, Val: 1.0656
# Epoch: 418, Loss: 0.6601, Train: 0.8122, Val: 1.0659
# Epoch: 419, Loss: 0.6599, Train: 0.8121, Val: 1.0660
# Epoch: 420, Loss: 0.6598, Train: 0.8120, Val: 1.0671
# Epoch: 421, Loss: 0.6597, Train: 0.8119, Val: 1.0669
# Epoch: 422, Loss: 0.6595, Train: 0.8118, Val: 1.0681
# Epoch: 423, Loss: 0.6593, Train: 0.8117, Val: 1.0681
# Epoch: 424, Loss: 0.6592, Train: 0.8116, Val: 1.0692
# Epoch: 425, Loss: 0.6590, Train: 0.8115, Val: 1.0696
# Epoch: 426, Loss: 0.6589, Train: 0.8114, Val: 1.0699
# Epoch: 427, Loss: 0.6587, Train: 0.8113, Val: 1.0709
# Epoch: 428, Loss: 0.6586, Train: 0.8112, Val: 1.0709
# Epoch: 429, Loss: 0.6584, Train: 0.8111, Val: 1.0718
# Epoch: 430, Loss: 0.6583, Train: 0.8110, Val: 1.0722
# Epoch: 431, Loss: 0.6581, Train: 0.8110, Val: 1.0734
# Epoch: 432, Loss: 0.6579, Train: 0.8109, Val: 1.0733
# Epoch: 433, Loss: 0.6578, Train: 0.8108, Val: 1.0744
# Epoch: 434, Loss: 0.6577, Train: 0.8107, Val: 1.0749
# Epoch: 435, Loss: 0.6575, Train: 0.8106, Val: 1.0757
# Epoch: 436, Loss: 0.6574, Train: 0.8105, Val: 1.0758
# Epoch: 437, Loss: 0.6572, Train: 0.8104, Val: 1.0772
# Epoch: 438, Loss: 0.6570, Train: 0.8103, Val: 1.0772
# Epoch: 439, Loss: 0.6569, Train: 0.8102, Val: 1.0784
# Epoch: 440, Loss: 0.6568, Train: 0.8101, Val: 1.0784
# Epoch: 441, Loss: 0.6566, Train: 0.8101, Val: 1.0797
# Epoch: 442, Loss: 0.6565, Train: 0.8100, Val: 1.0789
# Epoch: 443, Loss: 0.6564, Train: 0.8099, Val: 1.0813
# Epoch: 444, Loss: 0.6563, Train: 0.8098, Val: 1.0806
# Epoch: 445, Loss: 0.6562, Train: 0.8098, Val: 1.0822
# Epoch: 446, Loss: 0.6560, Train: 0.8096, Val: 1.0818
# Epoch: 447, Loss: 0.6558, Train: 0.8095, Val: 1.0832
# Epoch: 448, Loss: 0.6556, Train: 0.8094, Val: 1.0839
# Epoch: 449, Loss: 0.6555, Train: 0.8093, Val: 1.0842
# Epoch: 450, Loss: 0.6553, Train: 0.8093, Val: 1.0856
# Epoch: 451, Loss: 0.6553, Train: 0.8092, Val: 1.0850
# Epoch: 452, Loss: 0.6551, Train: 0.8092, Val: 1.0869
# Epoch: 453, Loss: 0.6550, Train: 0.8090, Val: 1.0859
# Epoch: 454, Loss: 0.6549, Train: 0.8090, Val: 1.0883
# Epoch: 455, Loss: 0.6547, Train: 0.8088, Val: 1.0876
# Epoch: 456, Loss: 0.6546, Train: 0.8087, Val: 1.0893
# Epoch: 457, Loss: 0.6544, Train: 0.8086, Val: 1.0900
# Epoch: 458, Loss: 0.6542, Train: 0.8085, Val: 1.0904
# Epoch: 459, Loss: 0.6541, Train: 0.8085, Val: 1.0933
# Epoch: 460, Loss: 0.6540, Train: 0.8084, Val: 1.0932
# Epoch: 461, Loss: 0.6538, Train: 0.8083, Val: 1.0957
# Epoch: 462, Loss: 0.6537, Train: 0.8082, Val: 1.0951
# Epoch: 463, Loss: 0.6535, Train: 0.8081, Val: 1.0982
# Epoch: 464, Loss: 0.6533, Train: 0.8079, Val: 1.0999
# Epoch: 465, Loss: 0.6530, Train: 0.8078, Val: 1.1058
# Epoch: 466, Loss: 0.6528, Train: 0.8079, Val: 1.1013
# Epoch: 467, Loss: 0.6531, Train: 0.8081, Val: 1.1107
# Epoch: 468, Loss: 0.6533, Train: 0.8080, Val: 1.1012
# Epoch: 469, Loss: 0.6533, Train: 0.8075, Val: 1.1081
# Epoch: 470, Loss: 0.6523, Train: 0.8072, Val: 1.1092
# Epoch: 471, Loss: 0.6519, Train: 0.8073, Val: 1.1063
# Epoch: 472, Loss: 0.6521, Train: 0.8072, Val: 1.1150
# Epoch: 473, Loss: 0.6519, Train: 0.8070, Val: 1.1082
# Epoch: 474, Loss: 0.6517, Train: 0.8067, Val: 1.1128
# Epoch: 475, Loss: 0.6510, Train: 0.8064, Val: 1.1138
# Epoch: 476, Loss: 0.6505, Train: 0.8064, Val: 1.1115
# Epoch: 477, Loss: 0.6507, Train: 0.8064, Val: 1.1189
# Epoch: 478, Loss: 0.6505, Train: 0.8061, Val: 1.1126
# Epoch: 479, Loss: 0.6502, Train: 0.8059, Val: 1.1184
# Epoch: 480, Loss: 0.6498, Train: 0.8056, Val: 1.1169
# Epoch: 481, Loss: 0.6493, Train: 0.8055, Val: 1.1180
# Epoch: 482, Loss: 0.6491, Train: 0.8055, Val: 1.1254
# Epoch: 483, Loss: 0.6491, Train: 0.8055, Val: 1.1176
# Epoch: 484, Loss: 0.6492, Train: 0.8053, Val: 1.1291
# Epoch: 485, Loss: 0.6488, Train: 0.8051, Val: 1.1207
# Epoch: 486, Loss: 0.6485, Train: 0.8047, Val: 1.1288
# Epoch: 487, Loss: 0.6478, Train: 0.8044, Val: 1.1264
# Epoch: 488, Loss: 0.6474, Train: 0.8042, Val: 1.1284
# Epoch: 489, Loss: 0.6471, Train: 0.8041, Val: 1.1330
# Epoch: 490, Loss: 0.6468, Train: 0.8041, Val: 1.1280
# Epoch: 491, Loss: 0.6468, Train: 0.8041, Val: 1.1391
# Epoch: 492, Loss: 0.6468, Train: 0.8045, Val: 1.1250
# Epoch: 493, Loss: 0.6476, Train: 0.8046, Val: 1.1432
# Epoch: 494, Loss: 0.6477, Train: 0.8044, Val: 1.1241
# Epoch: 495, Loss: 0.6474, Train: 0.8032, Val: 1.1368
# Epoch: 496, Loss: 0.6453, Train: 0.8032, Val: 1.1403
# Epoch: 497, Loss: 0.6453, Train: 0.8040, Val: 1.1268
# Epoch: 498, Loss: 0.6468, Train: 0.8035, Val: 1.1460
# Epoch: 499, Loss: 0.6458, Train: 0.8025, Val: 1.1337
# Epoch: 500, Loss: 0.6443, Train: 0.8022, Val: 1.1374

# %%
print(f'Loading model with val_rmse: {best_val_rmse:.4f} at epoch {best_epoch}')
model.load_state_dict(torch.load(model_file_name))

print("Test rmse:", test(model, test_data))
# Out:
# Loading model with val_rmse: 0.9662 at epoch 116
# Test rmse: 0.9572569727897644
